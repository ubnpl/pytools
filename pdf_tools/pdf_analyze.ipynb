# %% [markdown]
# # Import PDF and analyze

# %% [markdown]
# ## Test PyPDF2

# %%
import PyPDF2

# %%
# creating an object 
#file = open('nchemex.pdf', 'rb')
file = open('nchemex.pdf', 'rb')

# %%
# creating a pdf reader object
fileReader = PyPDF2.PdfFileReader(file)
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]

# %%
# print the number of pages in pdf file
print(fileReader.numPages)
# Out:
# 7

# %%
fileReader.documentInfo
# Out:
# {'/Author': 'Nuria Plattner',
#  '/CreationDate': "D:20170524121757+05'30'",
#  '/Creator': 'Arbortext Advanced Print Publisher 10.0.1465/W Unicode',
#  '/ModDate': "D:20170524134328+05'30'",
#  '/Producer': 'Acrobat Distiller 8.1.0 (Windows)',
#  '/Subject': 'Nature Chemistry (2017). doi:10.1038/nchem.2785',
#  '/Title': 'Complete protein-protein association kinetics in atomic detail revealed by molecular dynamics simulations and Markov modelling'}

# %%
page = fileReader.getPage(0)

# %%
page_content = page.extractText()

# %%
print (page_content.encode('utf-8'))
# Out:
# b'Completeprotein\n\xc5\x92proteinassociationkineticsin\natomicdetailrevealedbymoleculardynamics\n\nsimulationsandMarkovmodelling\nNuriaPlattner\n1*,StefanDoerr\n2,GianniDeFabritiis\n2,3\nandFrankNo\xc3\xa9\n1*Protein\n\xc5\x92proteinassociationisfundamentaltomanylifeprocesses.However,amicroscopicmodeldescribingthestructures\nandkineticsduringassociationanddissociationislackingonaccountofthelonglifetimesofassociatedstates,whichhave\n\npreventedef\ncientsamplingbydirectmoleculardynamics(MD)simulations.Herewedemonstrateprotein\n\xc5\x92protein\nassociationanddissociationinatomisticresolutionfortheribonucleasebarnaseanditsinhibitorbarstarbycombining\nadaptivehigh-throughputMDsimulationsandhiddenMarkovmodelling.Themodelrevealsexperimentallyconsistent\n\nintermediatestructures,energeticsandkineticsontimescalesfrommicrosecondstohours.Avarietyof\nexiblyattached\nintermediatesandmisboundstatesfunneldowntoatransitionstateandanativebasinconsistingofthelooselybound\nnear-nativestateandthetightlyboundcrystallographicstate.Theseresultsofferadeeperlevelofinsightinto\nmacromolecularrecognitionandourapproachopensthedoorforunderstandingandmanipulatingawiderangeof\n\nmacromolecularassociationprocesses.\nLifeprocessesarecriticallydependentontheformationofbio-\n\nmolecularcomplexes,andinparticular,protein\n\xc5\x92proteinassoci-\nation,whichmediatestheassemblyofcellularstructures,signal\ntransductionandinhibition,immuneresponseandproteinrecruit-\n\nmenttomembranescaffolds.Interactionsofproteinswithother\nmacromoleculesalsoplaykeyrolesinapplicationssuchasinhibition\nofproteinactivitybydrugs\n1,geneediting\n2andtheassemblyof\nnewmaterials\n3.Adeepunderstandingofsuchprocessesandtheabilitytofully\nplanandcontroltheirdesignwouldarisefromafullmapofthe\nconformationspaceoftheinteractingproteinpairs.Suchamicro-\nscopicmodelwouldinvolverepresentativesamplesofallstructures\n\n(bound,dissociated,intermediates,etc.)inatomicresolution,their\n\nequilibriumpopulationsandthetransitionratesbetweenthem.\nHowever,suchacompletemicroscopicpicturehasnotyetbeen\nachievedforprotein\n\xc5\x92proteininteraction.Experimentscanprobe\neitherindividualaspectsofthemicroscopicpictureoraveraged\n\nensembles,suchasthemoststablestructures,associationkinetics\n\nandbindingaf\nnities.Mutationalanalysescanidentifyamino\nacidsstabilizingassociatedstatesortransitionstates\n4.Thestructure\nofthetransientencountercomplex,thatis,thesetofstructures\n\nfoundimmediatelybeforethetransitionstateofproteinassociation,\n\nhasbeenprobedusingNMR\n5andcoarse-grainedsimulations\n6\xc5\x929.Bindingfreeenergiescanbecomputedfromatomisticsimulations\nwhentheboundposeispreciselyknown\n10,andthebindingfree\nenergylandscapecanbereconstructedusingmetadynamicsgiven\n\nasetofpre-de\nnedcollectivevariables\n11.Inferenceofkinetics\nthenrequiresakineticmodel\n12oradditionalunbiasedsimulations\n13.Acandidatetorevealacompletemicroscopicmodelofprotein\n\xc5\x92proteininteractionisunbiasedatomic-detailmoleculardynamics\n(MD)simulation.Microscopicmodelsofbiomolecularprocesses\n\nhaverecentlybeenachievedduetocombinedadvancesinhigh-\n\nperformancecomputingandMarkovmodelling\n14\xc5\x9219.Previous\nbindingstudies,however,havebeenlimitedtotheassociationof\nsmallligandstoproteinsandtheco-foldingofshorterpeptide\nchains16,19,20,orsmallpartsoftheassociationlandscapesuchas\nthedownhillbindingstepfromapre-boundpose\n21.Thesimulation\nofprotein\n\xc5\x92proteinassociationischallengedbythefactthat\ndissociationtimesexceedaccessibleMDsimulationlengthsbyfar,\nsuchthatlongMDsimulationswillgetstuckafterasingle\nbindingevent,possiblyeveninnon-nativetraps.\nHerewedemonstratehowreversibleprotein\n\xc5\x92proteinassociation\ncanbestudiedinatomisticdetailbycombininganextensiveand\n\nadaptivelygeneratedensembleofunbiasedmoleculardynamics\nsimulationswithhiddenMarkovmodelling.Wereproduce\nmeasuredstructures,energeticsandkineticsquantitativelyand\n\nobtainafullmicroscopicmodeloftheproteincomplexstructures,\n\nthermodynamicsandkinetics.\nRes ...

# %%
page_content
# Out:
# 'Completeprotein\nŒproteinassociationkineticsin\natomicdetailrevealedbymoleculardynamics\n\nsimulationsandMarkovmodelling\nNuriaPlattner\n1*,StefanDoerr\n2,GianniDeFabritiis\n2,3\nandFrankNoé\n1*Protein\nŒproteinassociationisfundamentaltomanylifeprocesses.However,amicroscopicmodeldescribingthestructures\nandkineticsduringassociationanddissociationislackingonaccountofthelonglifetimesofassociatedstates,whichhave\n\npreventedef\ncientsamplingbydirectmoleculardynamics(MD)simulations.Herewedemonstrateprotein\nŒprotein\nassociationanddissociationinatomisticresolutionfortheribonucleasebarnaseanditsinhibitorbarstarbycombining\nadaptivehigh-throughputMDsimulationsandhiddenMarkovmodelling.Themodelrevealsexperimentallyconsistent\n\nintermediatestructures,energeticsandkineticsontimescalesfrommicrosecondstohours.Avarietyof\nexiblyattached\nintermediatesandmisboundstatesfunneldowntoatransitionstateandanativebasinconsistingofthelooselybound\nnear-nativestateandthetightlyboundcrystallographicstate.Theseresultsofferadeeperlevelofinsightinto\nmacromolecularrecognitionandourapproachopensthedoorforunderstandingandmanipulatingawiderangeof\n\nmacromolecularassociationprocesses.\nLifeprocessesarecriticallydependentontheformationofbio-\n\nmolecularcomplexes,andinparticular,protein\nŒproteinassoci-\nation,whichmediatestheassemblyofcellularstructures,signal\ntransductionandinhibition,immuneresponseandproteinrecruit-\n\nmenttomembranescaffolds.Interactionsofproteinswithother\nmacromoleculesalsoplaykeyrolesinapplicationssuchasinhibition\nofproteinactivitybydrugs\n1,geneediting\n2andtheassemblyof\nnewmaterials\n3.Adeepunderstandingofsuchprocessesandtheabilitytofully\nplanandcontroltheirdesignwouldarisefromafullmapofthe\nconformationspaceoftheinteractingproteinpairs.Suchamicro-\nscopicmodelwouldinvolverepresentativesamplesofallstructures\n\n(bound,dissociated,intermediates,etc.)inatomicresolution,their\n\nequilibriumpopulationsandthetransitionratesbetweenthem.\nHowever,suchacompletemicroscopicpicturehasnotyetbeen\nachievedforprotein\nŒproteininteraction.Experimentscanprobe\neitherindividualaspectsofthemicroscopicpictureoraveraged\n\nensembles,suchasthemoststablestructures,associationkinetics\n\nandbindingaf\nnities.Mutationalanalysescanidentifyamino\nacidsstabilizingassociatedstatesortransitionstates\n4.Thestructure\nofthetransientencountercomplex,thatis,thesetofstructures\n\nfoundimmediatelybeforethetransitionstateofproteinassociation,\n\nhasbeenprobedusingNMR\n5andcoarse-grainedsimulations\n6Œ9.Bindingfreeenergiescanbecomputedfromatomisticsimulations\nwhentheboundposeispreciselyknown\n10,andthebindingfree\nenergylandscapecanbereconstructedusingmetadynamicsgiven\n\nasetofpre-de\nnedcollectivevariables\n11.Inferenceofkinetics\nthenrequiresakineticmodel\n12oradditionalunbiasedsimulations\n13.Acandidatetorevealacompletemicroscopicmodelofprotein\nŒproteininteractionisunbiasedatomic-detailmoleculardynamics\n(MD)simulation.Microscopicmodelsofbiomolecularprocesses\n\nhaverecentlybeenachievedduetocombinedadvancesinhigh-\n\nperformancecomputingandMarkovmodelling\n14Œ19.Previous\nbindingstudies,however,havebeenlimitedtotheassociationof\nsmallligandstoproteinsandtheco-foldingofshorterpeptide\nchains16,19,20,orsmallpartsoftheassociationlandscapesuchas\nthedownhillbindingstepfromapre-boundpose\n21.Thesimulation\nofprotein\nŒproteinassociationischallengedbythefactthat\ndissociationtimesexceedaccessibleMDsimulationlengthsbyfar,\nsuchthatlongMDsimulationswillgetstuckafterasingle\nbindingevent,possiblyeveninnon-nativetraps.\nHerewedemonstratehowreversibleprotein\nŒproteinassociation\ncanbestudiedinatomisticdetailbycombininganextensiveand\n\nadaptivelygeneratedensembleofunbiasedmoleculardynamics\nsimulationswithhiddenMarkovmodelling.Wereproduce\nmeasuredstructures,energeticsandkineticsquantitativelyand\n\nobtainafullmicroscopicmodeloftheproteincomplexstructures,\n\nthermodynamicsandkinetics.\nResultsanddiscussion\nAll-atomsimulationofreversibleprotein\nŒproteinassociation. ...

# %% [markdown]
# ## Test Tabula

# %%
from tabula import read_pdf

# %%
df = read_pdf('BJ-2008.pdf')

# %%
df

# %% [markdown]
# ## Test Tika

# %%
from tika import parser

# %%
parsedPDF = parser.from_file("nchemex.pdf")
# Out:
# 2020-02-17 16:53:13,786 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.19/tika-server-1.19.jar to /tmp/tika-server.jar.
# 2020-02-17 16:53:20,443 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.19/tika-server-1.19.jar.md5 to /tmp/tika-server.jar.md5.
# 2020-02-17 16:53:20,892 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...

# %%
parsedPDF
# Out:
# {'content': '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nComplete protein-protein association kinetics in atomic detail revealed by molecular dynamics simulations and Markov modelling\n\n\nComplete protein–protein association kinetics in\natomic detail revealed by molecular dynamics\nsimulations and Markov modelling\nNuria Plattner1*, Stefan Doerr2, Gianni De Fabritiis2,3 and Frank Noé1*\n\nProtein–protein association is fundamental to many life processes. However, a microscopic model describing the structures\nand kinetics during association and dissociation is lacking on account of the long lifetimes of associated states, which have\nprevented efficient sampling by direct molecular dynamics (MD) simulations. Here we demonstrate protein–protein\nassociation and dissociation in atomistic resolution for the ribonuclease barnase and its inhibitor barstar by combining\nadaptive high-throughput MD simulations and hidden Markov modelling. The model reveals experimentally consistent\nintermediate structures, energetics and kinetics on timescales from microseconds to hours. A variety of flexibly attached\nintermediates and misbound states funnel down to a transition state and a native basin consisting of the loosely bound\nnear-native state and the tightly bound crystallographic state. These results offer a deeper level of insight into\nmacromolecular recognition and our approach opens the door for understanding and manipulating a wide range of\nmacromolecular association processes.\n\nLife processes are critically dependent on the formation of bio-molecular complexes, and in particular, protein–protein associ-ation, which mediates the assembly of cellular structures, signal\ntransduction and inhibition, immune response and protein recruit-\nment to membrane scaffolds. Interactions of proteins with other\nmacromolecules also play key roles in applications such as inhibition\nof protein activity by drugs1, gene editing2 and the assembly of\nnew materials3.\n\nA deep understanding of such processes and the ability to fully\nplan and control their design would arise from a full map of the\nconformation space of the interacting protein pairs. Such a micro-\nscopic model would involve representative samples of all structures\n(bound, dissociated, intermediates, etc.) in atomic resolution, their\nequilibrium populations and the transition rates between them.\n\nHowever, such a complete microscopic picture has not yet been\nachieved for protein–protein interaction. Experiments can probe\neither individual aspects of the microscopic picture or averaged\nensembles, such as the most stable structures, association kinetics\nand binding affinities. Mutational analyses can identify amino\nacids stabilizing associated states or transition states4. The structure\nof the transient encounter complex, that is, the set of structures\nfound immediately before the transition state of protein association,\nhas been probed using NMR5 and coarse-grained simulations6–9.\nBinding free energies can be computed from atomistic simulations\nwhen the bound pose is precisely known10, and the binding free\nenergy landscape can be reconstructed using metadynamics given\na set of pre-defined collective variables11. Inference of kinetics\nthen requires a kinetic model12 or additional unbiased simulations13.\n\nA candidate to reveal a complete microscopic model of protein–\nprotein interaction is unbiased atomic-detail molecular dynamics\n(MD) simulation. Microscopic models of biomolecular processes\nhave recently been achieved due to combined advances in high-\nperformance computing and Markov modelling14–19. Previous\nbinding studies, however, have been limited to the association of\n\nsmall ligands to proteins and the co-folding of shorter peptide\nchains16,19,20, or small parts of the association landscape such as\nthe downhill binding step from a pre-bound pose21. The simulation\nof protein–p ...
#  'metadata': {'Author': ['Stefan Doerr',
#    'Gianni De Fabritiis',
#    'Frank Noé',
#    'Nuria Plattner'],
#   'Content-Encoding': 'ISO-8859-1',
#   'Content-Length': '-1',
#   'Content-Type': ['application/pdf', 'text/plain; charset=ISO-8859-1'],
#   'Creation-Date': '2017-05-24T06:47:57Z',
#   'Last-Modified': '2017-05-24T08:13:28Z',
#   'Last-Save-Date': '2017-05-24T08:13:28Z',
#   'X-Parsed-By': ['org.apache.tika.parser.DefaultParser',
#    'org.apache.tika.parser.pdf.PDFParser',
#    ['org.apache.tika.parser.DefaultParser',
#     'org.apache.tika.parser.txt.TXTParser']],
#   'X-TIKA:embedded_resource_path': '/folder.joboptions',
#   'X-TIKA:origResourceName': 'folder.joboptions',
#   'X-TIKA:parse_time_millis': ['1144', '49'],
#   'access_permission:assemble_document': 'true',
#   'access_permission:can_modify': 'true',
#   'access_permission:can_print': 'true',
#   'access_permission:can_print_degraded': 'true',
#   'access_permission:extract_content': 'true',
#   'access_permission:extract_for_accessibility': 'true',
#   'access_permission:fill_in_form': 'true',
#   'access_permission:modify_annotations': 'true',
#   'cp:subject': 'Nature Chemistry (2017). doi:10.1038/nchem.2785',
#   'created': '2017-05-24T06:47:57Z',
#   'creator': ['Stefan Doerr',
#    'Gianni De Fabritiis',
#    'Frank Noé',
#    'Nuria Plattner'],
#   'date': '2017-05-24T08:13:28Z',
#   'dc:creator': ['Stefan Doerr',
#    'Gianni De Fabritiis',
#    'Frank Noé',
#    'Nuria Plattner'],
#   'dc:description': 'Nature Chemistry (2017). doi:10.1038/nchem.2785',
#   'dc:format': 'application/pdf; version=1.3',
#   'dc:title': 'Complete protein-protein association kinetics in atomic detail revealed by molecular dynamics simulations and Markov modelling',
#   'dcterms:created': '2017-05-24T06:47:57Z',
#   'dcterms:modified': '2017-05-24T08:13:28Z',
#   'description': 'Nature Chemistry (2017). doi:10.1038/nchem.2785',
#   'embeddedResourceType': 'ATTACHMENT',
#   'meta:author': ['Stefan Doerr',
#    'Gianni De Fabritiis',
#    'Frank Noé',
#    'Nuria Plattner'],
#   'meta:creation-date': '2017-05-24T06:47:57Z',
#   'meta:save-date': '2017-05-24T08:13:28Z',
#   'modified': '2017-05-24T08:13:28Z',
#   'pdf:PDFVersion': '1.3',
#   'pdf:docinfo:created': '2017-05-24T06:47:57Z',
#   'pdf:docinfo:creator': 'Nuria Plattner',
#   'pdf:docinfo:creator_tool': 'Arbortext Advanced Print Publisher 10.0.1465/W Unicode',
#   'pdf:docinfo:modified': '2017-05-24T08:13:28Z',
#   'pdf:docinfo:producer': 'Acrobat Distiller 8.1.0 (Windows)',
#   'pdf:docinfo:subject': 'Nature Chemistry (2017). doi:10.1038/nchem.2785',
#   'pdf:docinfo:title': 'Complete protein-protein association kinetics in atomic detail revealed by molecular dynamics simulations and Markov modelling',
#   'pdf:encrypted': 'false',
#   'producer': 'Acrobat Distiller 8.1.0 (Windows)',
#   'resourceName': ['nchemex.pdf', 'folder.joboptions'],
#   'subject': 'Nature Chemistry (2017). doi:10.1038/nchem.2785',
#   'title': 'Complete protein-protein association kinetics in atomic detail revealed by molecular dynamics simulations and Markov modelling',
#   'xmp:CreatorTool': 'Arbortext Advanced Print Publisher 10.0.1465/W Unicode',
#   'xmpMM:DocumentID': 'uuid:03d04121-f0e7-347f-b6a1-e56cb26a998e',
#   'xmpTPg:NPages': '7'},
#  'status': 200}

# %%
parsedPDF.keys()
# Out:
# dict_keys(['status', 'content', 'metadata'])

# %%
parsedPDF['content']
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nComplete protein-protein association kinetics in atomic detail revealed by molecular dynamics simulations and Markov modelling\n\n\nComplete protein–protein association kinetics in\natomic detail revealed by molecular dynamics\nsimulations and Markov modelling\nNuria Plattner1*, Stefan Doerr2, Gianni De Fabritiis2,3 and Frank Noé1*\n\nProtein–protein association is fundamental to many life processes. However, a microscopic model describing the structures\nand kinetics during association and dissociation is lacking on account of the long lifetimes of associated states, which have\nprevented efficient sampling by direct molecular dynamics (MD) simulations. Here we demonstrate protein–protein\nassociation and dissociation in atomistic resolution for the ribonuclease barnase and its inhibitor barstar by combining\nadaptive high-throughput MD simulations and hidden Markov modelling. The model reveals experimentally consistent\nintermediate structures, energetics and kinetics on timescales from microseconds to hours. A variety of flexibly attached\nintermediates and misbound states funnel down to a transition state and a native basin consisting of the loosely bound\nnear-native state and the tightly bound crystallographic state. These results offer a deeper level of insight into\nmacromolecular recognition and our approach opens the door for understanding and manipulating a wide range of\nmacromolecular association processes.\n\nLife processes are critically dependent on the formation of bio-molecular complexes, and in particular, protein–protein associ-ation, which mediates the assembly of cellular structures, signal\ntransduction and inhibition, immune response and protein recruit-\nment to membrane scaffolds. Interactions of proteins with other\nmacromolecules also play key roles in applications such as inhibition\nof protein activity by drugs1, gene editing2 and the assembly of\nnew materials3.\n\nA deep understanding of such processes and the ability to fully\nplan and control their design would arise from a full map of the\nconformation space of the interacting protein pairs. Such a micro-\nscopic model would involve representative samples of all structures\n(bound, dissociated, intermediates, etc.) in atomic resolution, their\nequilibrium populations and the transition rates between them.\n\nHowever, such a complete microscopic picture has not yet been\nachieved for protein–protein interaction. Experiments can probe\neither individual aspects of the microscopic picture or averaged\nensembles, such as the most stable structures, association kinetics\nand binding affinities. Mutational analyses can identify amino\nacids stabilizing associated states or transition states4. The structure\nof the transient encounter complex, that is, the set of structures\nfound immediately before the transition state of protein association,\nhas been probed using NMR5 and coarse-grained simulations6–9.\nBinding free energies can be computed from atomistic simulations\nwhen the bound pose is precisely known10, and the binding free\nenergy landscape can be reconstructed using metadynamics given\na set of pre-defined collective variables11. Inference of kinetics\nthen requires a kinetic model12 or additional unbiased simulations13.\n\nA candidate to reveal a complete microscopic model of protein–\nprotein interaction is unbiased atomic-detail molecular dynamics\n(MD) simulation. Microscopic models of biomolecular processes\nhave recently been achieved due to combined advances in high-\nperformance computing and Markov modelling14–19. Previous\nbinding studies, however, have been limited to the association of\n\nsmall ligands to proteins and the co-folding of shorter peptide\nchains16,19,20, or small parts of the association landscape such as\nthe downhill binding step from a pre-bound pose21. The simulation\nof protein–protein assoc ...

# %%
parsedPDF['metadata']
# Out:
# {'Author': ['Stefan Doerr',
#   'Gianni De Fabritiis',
#   'Frank Noé',
#   'Nuria Plattner'],
#  'Content-Encoding': 'ISO-8859-1',
#  'Content-Length': '-1',
#  'Content-Type': ['application/pdf', 'text/plain; charset=ISO-8859-1'],
#  'Creation-Date': '2017-05-24T06:47:57Z',
#  'Last-Modified': '2017-05-24T08:13:28Z',
#  'Last-Save-Date': '2017-05-24T08:13:28Z',
#  'X-Parsed-By': ['org.apache.tika.parser.DefaultParser',
#   'org.apache.tika.parser.pdf.PDFParser',
#   ['org.apache.tika.parser.DefaultParser',
#    'org.apache.tika.parser.txt.TXTParser']],
#  'X-TIKA:embedded_resource_path': '/folder.joboptions',
#  'X-TIKA:origResourceName': 'folder.joboptions',
#  'X-TIKA:parse_time_millis': ['1144', '49'],
#  'access_permission:assemble_document': 'true',
#  'access_permission:can_modify': 'true',
#  'access_permission:can_print': 'true',
#  'access_permission:can_print_degraded': 'true',
#  'access_permission:extract_content': 'true',
#  'access_permission:extract_for_accessibility': 'true',
#  'access_permission:fill_in_form': 'true',
#  'access_permission:modify_annotations': 'true',
#  'cp:subject': 'Nature Chemistry (2017). doi:10.1038/nchem.2785',
#  'created': '2017-05-24T06:47:57Z',
#  'creator': ['Stefan Doerr',
#   'Gianni De Fabritiis',
#   'Frank Noé',
#   'Nuria Plattner'],
#  'date': '2017-05-24T08:13:28Z',
#  'dc:creator': ['Stefan Doerr',
#   'Gianni De Fabritiis',
#   'Frank Noé',
#   'Nuria Plattner'],
#  'dc:description': 'Nature Chemistry (2017). doi:10.1038/nchem.2785',
#  'dc:format': 'application/pdf; version=1.3',
#  'dc:title': 'Complete protein-protein association kinetics in atomic detail revealed by molecular dynamics simulations and Markov modelling',
#  'dcterms:created': '2017-05-24T06:47:57Z',
#  'dcterms:modified': '2017-05-24T08:13:28Z',
#  'description': 'Nature Chemistry (2017). doi:10.1038/nchem.2785',
#  'embeddedResourceType': 'ATTACHMENT',
#  'meta:author': ['Stefan Doerr',
#   'Gianni De Fabritiis',
#   'Frank Noé',
#   'Nuria Plattner'],
#  'meta:creation-date': '2017-05-24T06:47:57Z',
#  'meta:save-date': '2017-05-24T08:13:28Z',
#  'modified': '2017-05-24T08:13:28Z',
#  'pdf:PDFVersion': '1.3',
#  'pdf:docinfo:created': '2017-05-24T06:47:57Z',
#  'pdf:docinfo:creator': 'Nuria Plattner',
#  'pdf:docinfo:creator_tool': 'Arbortext Advanced Print Publisher 10.0.1465/W Unicode',
#  'pdf:docinfo:modified': '2017-05-24T08:13:28Z',
#  'pdf:docinfo:producer': 'Acrobat Distiller 8.1.0 (Windows)',
#  'pdf:docinfo:subject': 'Nature Chemistry (2017). doi:10.1038/nchem.2785',
#  'pdf:docinfo:title': 'Complete protein-protein association kinetics in atomic detail revealed by molecular dynamics simulations and Markov modelling',
#  'pdf:encrypted': 'false',
#  'producer': 'Acrobat Distiller 8.1.0 (Windows)',
#  'resourceName': ['nchemex.pdf', 'folder.joboptions'],
#  'subject': 'Nature Chemistry (2017). doi:10.1038/nchem.2785',
#  'title': 'Complete protein-protein association kinetics in atomic detail revealed by molecular dynamics simulations and Markov modelling',
#  'xmp:CreatorTool': 'Arbortext Advanced Print Publisher 10.0.1465/W Unicode',
#  'xmpMM:DocumentID': 'uuid:03d04121-f0e7-347f-b6a1-e56cb26a998e',
#  'xmpTPg:NPages': '7'}

# %%
cont = parsedPDF['content']

# %%
cont.split('\n')
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Complete protein-protein association kinetics in atomic detail revealed by molecular dynamics simulations and Markov modelling',
#  '',
#  '',
#  'Complete protein–protein association kinetics in',
#  'atomic detail revealed by molecular dynamics',
#  'simulations and Markov modelling',
#  'Nuria Plattner1*, Stefan Doerr2, Gianni De Fabritiis2,3 and Frank Noé1*',
#  '',
#  'Protein–protein association is fundamental to many life processes. However, a microscopic model describing the structures',
#  'and kinetics during association and dissociation is lacking on account of the long lifetimes of associated states, which have',
#  'prevented efficient sampling by direct molecular dynamics (MD) simulations. Here we demonstrate protein–protein',
#  'association and dissociation in atomistic resolution for the ribonuclease barnase and its inhibitor barstar by combining',
#  'adaptive high-throughput MD simulations and hidden Markov modelling. The model reveals experimentally consistent',
#  'intermediate structures, energetics and kinetics on timescales from microseconds to hours. A variety of flexibly attached',
#  'intermediates and misbound states funnel down to a transition state and a native basin consisting of the loosely bound',
#  'near-native state and the tightly bound crystallographic state. These results offer a deeper level of insight into',
#  'macromolecular recognition and our approach opens the door for understanding and manipulating a wide range of',
#  'macromolecular association processes.',
#  '',
#  'Life processes are critically dependent on the formation of bio-molecular complexes, and in particular, protein–protein associ-ation, which mediates the assembly of cellular structures, signal',
#  'transduction and inhibition, immune response and protein recruit-',
#  'ment to membrane scaffolds. Interactions of proteins with other',
#  'macromolecules also play key roles in applications such as inhibition',
#  'of protein activity by drugs1, gene editing2 and the assembly of',
#  'new materials3.',
#  '',
#  'A deep understanding of such processes and the ability to fully',
#  'plan and control their design would arise from a full map of the',
#  'conformation space of the interacting protein pairs. Such a micro-',
#  'scopic model would involve representative samples of all structures',
#  '(bound, dissociated, intermediates, etc.) in atomic resolution, their',
#  'equilibrium populations and the transition rates between them.',
#  '',
#  'However, such a complete microscopic picture has not yet been',
#  'achieved for protein–protein interaction. Experiments can probe',
#  'either individual aspects of the microscopic picture or averaged',
#  'ensembles, such as the most stable structures, association kinetics',
#  'and binding affinities. Mutational analyses can identify amino',
#  'acids stabilizing associated states or transition states4. The structure',
#  'of the transient encounter complex, that is, the set of structures',
#  'found immediately before the transition state of protein association,',
#  'has been probed using NMR5 and coarse-grained simulations6–9.',
#  'Binding free energies can be computed from atomistic simulations',
#  'when the bound pose is precisely known10, and the binding free',
#  'energy landscape can be reconstructed using metadynamics given',
#  'a set of pre-defined collective variables11. Inference of kinetics',
#  'then requires a kinetic model12 or additional unbiased simulations13.',
#  '',
#  'A candidate to reveal a complete microscopic model of protein–',
#  'protein interaction is unbiased atomic-detail molecular dynamics',
#  '(MD) simulation. Microscopic models of biomolecular processes',
#  'have recently been achieved due to combined advances in high-',
#  'performance computing and Markov modelling14–19. Previous',
#  'binding studies, however, have been limited to the association of',
#  '',
#  'small ligands to proteins and the co-folding of shorter peptide',
#  'chains16,19,20, or small parts of the association landscape such as',
#  'the downhill binding step from a pre-bound pose21. The simulation',
#  'of protein–protein association is challenged by the fact that',
#  'dissociation times exceed accessible MD simulation lengths by far,',
#  'such that long MD simulations will get stuck after a single',
#  'binding event, possibly even in non-native traps.',
#  '',
#  'Here we demonstrate how reversible protein–protein association',
#  'can be studied in atomistic detail by combining an extensive and',
#  'adaptively generated ensemble of unbiased molecular dynamics',
#  'simulations with hidden Markov modelling. We reproduce',
#  'measured structures, energetics and kinetics quantitatively and',
#  'obtain a full microscopic model of the protein complex structures,',
#  'thermodynamics and kinetics.',
#  '',
#  'Results and discussion',
#  'All-atom simulation of reversible protein–protein association. As',
#  'a prototypical example, we study the diffusion-limited association of',
#  'the experimentally well-characterized bacterial ribonuclease barnase',
#  'with its inhibitor barstar22,23. All-atom models of barnase wild type',
#  'and barstar pseudo wild type24 were immersed in a solvent box',
#  '(approximately 90,000 atoms). Several thousand unbiased molecular',
#  'dynamics (MD) simulations of 2 milliseconds aggregate length were',
#  'conducted in an automated high-throughput manner. These data',
#  'include 1.7 milliseconds of independent trajectories starting from',
#  'the dissociated state and 0.3 milliseconds in adaptive MD simulations.',
#  '',
#  'The adaptive MD launched periods of multiple parallel MD',
#  'trajectories, and the starting points of each period were selected so',
#  'as to favour the exploration of new states (Methods, Supplementary',
#  'Methods 1). This strategy can yield large speed-ups compared to',
#  'non-adaptive MD runs because slow processes with large energy',
#  'barriers are broken down into steps with individually smaller',
#  'barriers that can be sampled efficiently25–27 (Fig. 1a,b). When starting',
#  'from the dissociated state, both adaptive and non-adaptive',
#  '',
#  '1Department of Mathematics and Computer Science, Freie Universität Berlin, Arnimallee 6, 14195 Berlin, Germany. 2Computational Biophysics Laboratory',
#  '(GRIB-IMIM), Universitat Pompeu Fabra, Barcelona Biomedical Research Park (PRBB), C/ Doctor Aiguader 88, 08003 Barcelona, Spain. 3Institució Catalana',
#  'de Recerca i Estudis Avançats (ICREA), Passeig Lluis Companys 23, 08010 Barcelona, Spain. *e-mail: nuria.plattner@fu-berlin.de; frank.noe@fu-berlin.de',
#  '',
#  'ARTICLES',
#  'PUBLISHED ONLINE: 5 JUNE 2017 | DOI: 10.1038/NCHEM.2785',
#  '',
#  'NATURE CHEMISTRY | ADVANCE ONLINE PUBLICATION | www.nature.com/naturechemistry 1',
#  '',
#  '© 2017 Macmillan Publishers Limited, part of Springer Nature. All rights reserved.',
#  '',
#  'mailto:nuria.plattner@fu-berlin.de',
#  'mailto:frank.noe@fu-berlin.de',
#  'http://dx.doi.org/10.1038/nchem.2785',
#  'http://www.nature.com/naturechemistry',
#  '',
#  '',
#  'simulations reproducibly found the native bound complex. Adaptive',
#  'simulations required a total simulation effort of a few microseconds,',
#  'roughly an order of magnitude speed-up compared to an equilibrium',
#  'binding time of a tens of microseconds (Supplementary Fig. 1).',
#  'Surprisingly, the adaptive MD runs could also reproducibly reach',
#  'the dissociated state when starting from the crystal structure using',
#  'a total simulation effort of a few hundred microseconds, although',
#  'the expected dissociation time is hours (Supplementary Fig. 1).',
#  '',
#  'A first analysis shows that the total dataset contains several',
#  'thousand unspecific association and dissociation events, about 90',
#  'binding events from non-native associated states to native and 10',
#  'unbinding events (Fig. 1c).',
#  '',
#  'Equilibrium kinetics model and validation. Although the',
#  'individual simulations are not started from an equilibrium',
#  'distribution and are shorter than binding and dissociation',
#  'timescales, Markov modelling approaches can combine such a',
#  'trajectory ensemble towards unbiased equilibrium models of the',
#  'long-timescale kinetics and thermodynamics (Fig. 1a)28,29. Here, a',
#  'hidden Markov model (HMM) was built to estimate a network of',
#  '',
#  'states, associated protein structures, and transition rates30. The',
#  'HMM is coupled to a diffusive association model inspired by a',
#  'previous study31 in order to be able to predict concentration-',
#  'dependent association rates and binding free energies (Methods,',
#  'Supplementary Methods 3–7).',
#  '',
#  'As the data contains only a few unbinding events, the following',
#  'computed quantities have large uncertainties but are statistically',
#  'consistent with experiment, which will be exploited to compute',
#  'consensus models of experimental and simulation data (intervals',
#  'are 95% confidence): (i) binding free energy lies between 12 and',
#  '19 kcal mol–1 (experimental 16.8 kcal mol–1; see Supplementary',
#  'Methods 5), (ii) the dissociation rate lies in the range of 3 × 10–6',
#  '',
#  'to 1 × 10–1 s–1 (measurements lie in the range of 4.8 × 10–5 to',
#  '5.0 × 10–4 s–1; see Supplementary Methods 6).',
#  '',
#  'The model successfully predicts the following quantities: (iii)',
#  'crystal structure 1BRS is predicted to be the most stable state, and',
#  'the simulated structures assigned to it have an average RMSD of',
#  '0.21 nm to 1BRS, (iv) association rate is predicted to be 2.63 × 108',
#  '',
#  'to 2.65 × 108 s–1 M–1 (1 × 108 to 3.4 × 108 s–1 M–1 measured pre-',
#  'viously23,32), (v) using perturbation theory33, binding free energy',
#  'changes of 35 mutant sequences reported in23,32 were predicted',
#  'within statistical error (Fig. 2a and Supplementary Methods 9),',
#  '(vi) although this approach cannot compute absolute values of',
#  'association rates of mutants, the computed change in transition',
#  'state energy is an excellent predictor for the change in the experimental',
#  'on-rate (Fig. 2b).',
#  '',
#  'Overall binding mechanism. Having validated our model with a',
#  'large set of experimental data we proceeded to examine properties',
#  'that are more difficult to probe directly by experiments. Figure 2c,',
#  'd displays the overall mechanisms and structures found along the',
#  'binding pathways. The proteins initially associate to non-native',
#  '(large RMSD) states. At that point, they can dissociate and re-',
#  'associate or stay in contact and rearrange towards the native',
#  'complex (Fig. 2c–f ).',
#  '',
#  'At the high protein concentration in the simulation, initial',
#  'association occurs within tens of nanoseconds and with no detect-',
#  'able barrier. The initial association of barstar can occur at all',
#  'locations on the barnase surface. During the first microsecond,',
#  'the complex preferentially populates early intermediates with',
#  'barstar located opposite of the barnase binding site (orange states',
#  'in Fig. 2d). However, association can also occur directly into the',
#  'late intermediate and mis-bound states (blue/red states in Fig. 2d),',
#  'where barstar is located in or near the barnase binding groove,',
#  'but not in the native orientation. The preference for initially associ-',
#  'ating to locations away from the binding pocket can be explained by',
#  'the fact that these states cover a larger fraction of the surface. The',
#  'initial association preference depends on the salt concentration;',
#  'with enhanced steering to the binding site being expected when',
#  'charge screening is reduced7,22. Knocking out intermediate states',
#  'by removing them from the HMM showed that individual early',
#  'intermediates have no significant effect on the association rate,',
#  'and even removing all early intermediates only reduces the',
#  'association rate by 20% (Supplementary Table 2).',
#  '',
#  'On timescales of 1–10 µs, the population shifts toward the late',
#  'intermediates and mis-bound states (blue/red states in Figs 2d',
#  'and 5c), which have higher equilibrium populations than the',
#  'early intermediates. Of special interest is the mis-bound state',
#  '(red), that has barstar bound ‘upside down’. This state does not',
#  'have a well-defined binding interface, but a few non-native inter-',
#  'actions such as barnase Arg 83 or Arg 87 with barstar Glu 118',
#  'occur with significant probability (Supplementary Figs 3 and 4).',
#  'Intermediate states are kinetically well connected and have lifetimes',
#  'on the order of one microsecond each (Supplementary Fig. 2).',
#  'Removing the late intermediates would reduce the binding rate by',
#  'a factor of 2.5 (Supplementary Table 2)',
#  '',
#  '1 2',
#  '',
#  '3',
#  '4',
#  '',
#  '5 Sampling strategy ',
#  '',
#  'Markov model ',
#  '',
#  'Trajectories',
#  '',
#  'Tasks',
#  '',
#  'Data ',
#  'generation ',
#  '',
#  'Model building ',
#  '',
#  'Compute clusterClientba',
#  '',
#  'c',
#  '',
#  'AssociatedDissociated Bound',
#  '',
#  'Time (μs) Time (μs)',
#  '',
#  '2,867',
#  '',
#  'D',
#  'is',
#  '',
#  'ta',
#  'nc',
#  '',
#  'e ',
#  '(n',
#  '',
#  'm',
#  ')',
#  '',
#  'R',
#  'M',
#  '',
#  'S',
#  'D',
#  '',
#  ' (',
#  'nm',
#  '',
#  ')',
#  '',
#  '86',
#  '6',
#  '',
#  '0',
#  '0 0.5 0',
#  '',
#  '0',
#  '',
#  '1.5',
#  '',
#  '5',
#  '',
#  'Time (μs) Time (μs)',
#  '',
#  'R',
#  'M',
#  '',
#  'S',
#  'D',
#  '',
#  ' (',
#  'nm',
#  '',
#  ')',
#  '',
#  'D',
#  'is',
#  '',
#  'ta',
#  'nc',
#  '',
#  'e ',
#  '(n',
#  '',
#  'm',
#  ') 101,465',
#  '',
#  '6',
#  '',
#  '0',
#  '0 3.5 0 7',
#  '',
#  '0',
#  '',
#  '1.5',
#  '',
#  'Figure 1 | Simulation of protein–protein association and dissociation.',
#  'a, Scheme of a large-barrier process such as protein–protein dissociation that',
#  'can be subdivided into multiple steps. Such processes can be sampled by',
#  'combining adaptively seeded simulation trajectories between individual steps',
#  'via Markov modelling. b, Schematic outline of adaptive sampling process.',
#  'c, Total number of full association–dissociation and binding–unbinding',
#  'transitions evaluated by raw trajectory statistics of all barnase–barstar',
#  'simulation trajectories used subsequently. An association–dissociation',
#  'transition was counted when a trajectory moved from a state where the',
#  'proteins had a minimum distance between heavy atom pairs of >2 nm to',
#  '<0.3 nm, and vice versa. A binding–unbinding event was counted when a',
#  'trajectory moved from a state with minimum heavy-atom RMSD from the',
#  'crystallographic structure >1 nm to RMSD <0.3 nm, and vice versa. For each',
#  'trajectory only one count was made in order to avoid duplicate counting',
#  'of recrossing events. Three sample trajectory snippets are shown for each',
#  'type of transition.',
#  '',
#  'ARTICLES NATURE CHEMISTRY DOI: 10.1038/NCHEM.2785',
#  '',
#  'NATURE CHEMISTRY | ADVANCE ONLINE PUBLICATION | www.nature.com/naturechemistry2',
#  '',
#  '© 2017 Macmillan Publishers Limited, part of Springer Nature. All rights reserved.',
#  '',
#  'http://dx.doi.org/10.1038/nchem.2785',
#  'http://www.nature.com/naturechemistry',
#  '',
#  '',
#  'Misbound',
#  '',
#  'Early intermediates',
#  '',
#  'Late',
#  'intermediate 2',
#  '',
#  'Late',
#  'intermediate 1',
#  '',
#  'Pre-bound',
#  '',
#  'Loosely',
#  'bound',
#  '',
#  'Tightly',
#  'bound',
#  '',
#  'a',
#  '',
#  'd',
#  '',
#  'b c e',
#  '',
#  'f',
#  '',
#  'g',
#  '',
#  'Dissociated',
#  '',
#  'Association',
#  '',
#  'Binding',
#  '',
#  'Unbinding Rebinding',
#  '',
#  '12',
#  'ΔΔ',
#  '',
#  'G',
#  ' e',
#  '',
#  'xp',
#  'er',
#  '',
#  'im',
#  'en',
#  '',
#  't (',
#  'kc',
#  '',
#  'al',
#  ' m',
#  '',
#  'ol',
#  '–1',
#  '',
#  ')',
#  '',
#  '8',
#  '',
#  '4',
#  '',
#  '–4 0',
#  '',
#  'ΔΔG model (kcal mol–1)',
#  '',
#  '4 8 12',
#  '',
#  '–4',
#  '',
#  '0',
#  '',
#  '3',
#  '',
#  '2',
#  '',
#  '2',
#  '',
#  '0',
#  '',
#  'ΔΔ',
#  'G',
#  '',
#  'on',
#  ' e',
#  '',
#  'xp',
#  'er',
#  '',
#  'im',
#  'en',
#  '',
#  't (',
#  'kc',
#  '',
#  'al',
#  ' m',
#  '',
#  'ol',
#  '–1',
#  '',
#  ')',
#  '',
#  '–5 0 5 10',
#  '',
#  'ΔΔGTS model (kcal mol–1)',
#  '',
#  '–2',
#  '',
#  '–1 F',
#  're',
#  '',
#  'e ',
#  'en',
#  '',
#  'er',
#  'gy',
#  '',
#  ' (',
#  'kT',
#  '',
#  ')',
#  '',
#  'Minimal distance (nm)',
#  '',
#  '3.0 24',
#  '',
#  '21',
#  '',
#  '18',
#  '',
#  '15',
#  '',
#  '12',
#  '',
#  '9',
#  '',
#  '6',
#  '',
#  '3',
#  '',
#  '0',
#  '',
#  '2.5',
#  '',
#  '2.0',
#  '',
#  'R',
#  'M',
#  '',
#  'S',
#  'D',
#  '',
#  ' (',
#  'nm',
#  '',
#  ')',
#  '',
#  '0.3',
#  '0.2',
#  '0.1',
#  '',
#  '0.00 0.02 0.04 0.06 0.08 0.10',
#  '',
#  '5',
#  '',
#  't t+50 t+100 t+150 t+200',
#  '',
#  '10 15 20 25 30',
#  '',
#  '0.3',
#  '0.2',
#  '0.1',
#  '',
#  '0.3',
#  '0.2',
#  '0.1',
#  '',
#  'R',
#  'M',
#  '',
#  'S',
#  'D',
#  '',
#  ' (',
#  'nm',
#  '',
#  ')',
#  'R',
#  '',
#  'M',
#  'S',
#  '',
#  'D',
#  ' (',
#  '',
#  'nm',
#  ')',
#  '',
#  'R',
#  'M',
#  '',
#  'S',
#  'D',
#  '',
#  ' (',
#  'nm',
#  '',
#  ')',
#  '',
#  '1.5',
#  '',
#  '1.0',
#  '',
#  '0.5',
#  '',
#  '0.25 0.50 1.00 2.00 4.00',
#  '',
#  'Time (μs)',
#  '',
#  'Figure 2 | Kinetic model of barnase–barstar association. a,b, Comparison of experimental and predicted changes in binding free energies and association',
#  'rates for all 35 single and double alanine mutations from Table II of ref. 23 and Table I of ref. 32. Statistical confidence intervals of the model are indicated in',
#  'white (1-σ, 68% confidence) and grey (2-σ, 95% confidence). a, Changes in binding free energy (ΔΔG) are predicted within statistical error. b, Comparison',
#  'of the computed changes in barrier height of the binding transition with changes of apparent association transition state energy, computed as ΔΔGon,apparent',
#  '= –kBTln(kon',
#  '',
#  'mutant/kon',
#  'wt), where kBT= 0.598 kcal mol',
#  '',
#  '–1 and kon',
#  'mutant, kon',
#  '',
#  'wt are the experimental association rates of mutant and wild type, respectively. The model',
#  'prediction was computed as free energy difference between the pre-bound state as a proxy for the transition state, and all early intermediate, late',
#  'intermediate and mis-bound states. c, Free energy surface over protein–protein heavy atom minimal distance and minimal RMSD to the native complex.',
#  'Shown is a contour plot of –kTlnμ(x) evaluated for each trajectory sample x, where kT is the thermal energy and μ(x) is the equilibrium weight of each',
#  'sample computed by the HMM (see Supplementary Methods 4). d, Kinetic network between metastable states with lifetimes on the order of microseconds.',
#  'Only transition rate constants ≥0.2ms–1 are shown. Arrow thickness is proportional to rate constant, disc area is proportional to square root of state',
#  'population. Structures are centered on barnase (orange) with its binding groove on top and its N-terminal helix on the bottom. Barstar is shown in grey with',
#  'its binding domain in green. Grey clouds show overlay of approximately 20 barstar conformations, sampled randomly from the corresponding metastable',
#  'states. e–g, Minimal RMSD to crystallographic complex shown for sample trajectories generated from the HMM (see Supplementary Methods 4). Initial',
#  'association (e), binding to the native complex (f), and geminate rebinding after being bound for a long time t (one hour on average; g).',
#  '',
#  'NATURE CHEMISTRY DOI: 10.1038/NCHEM.2785 ARTICLES',
#  '',
#  'NATURE CHEMISTRY | ADVANCE ONLINE PUBLICATION | www.nature.com/naturechemistry 3',
#  '',
#  '© 2017 Macmillan Publishers Limited, part of Springer Nature. All rights reserved.',
#  '',
#  'http://dx.doi.org/10.1038/nchem.2785',
#  'http://www.nature.com/naturechemistry',
#  '',
#  '',
#  'On timescales of 10–100 µs, the complex passes through a',
#  'pre-bound state (magenta in Figs 2d and 5c) and then continues',
#  'to the natively bound complex (grey states in Figs 2d and 5c),',
#  'which consists of a loosely bound and a tightly bound substate',
#  'that exchange on the microsecond timescale.',
#  '',
#  'Nature of the transition state of binding. The kinetic bottleneck',
#  'between the intermediate states and natively bound states is the',
#  'mandatory passage through the pre-bound state (magenta in Fig. 2d),',
#  'that is hence an on-pathway intermediate. Both the transition into',
#  'the pre-bound state and the binding from the pre-bound state',
#  'involve barriers (Supplementary Fig. 6). We refer to these barriers',
#  'collectively as transition state of binding as they are rate-limiting at',
#  'sufficiently high protein concentrations (Supplementary Fig. 5).',
#  '',
#  'The transition from the late intermediates through the pre-bound',
#  'state into the loosely bound state is characterized by two microscopic',
#  'pathways, in which barstar interacts with either of the two barnase',
#  'loops surrounding the binding groove: the ‘left’ loop including Ser',
#  '',
#  '38 and the ‘right’ RNA recognition loop of barnase including Arg',
#  '59 (Fig. 3) whose importance for steering of the two protein has',
#  'been shown before6,7. Due to the flexibility of both loop regions,',
#  'barstar can “swing” around its attachment point, giving rise to a',
#  'quite flexible set of structures. These pathways are not separated by',
#  'significant barriers, i.e. the complex can change between “left” and',
#  '“right” attachment point multiple times before binding.',
#  '',
#  'The minor left pathway (5% population, Fig. 3a→ c→ e) involves',
#  'different possible protein contacts, including hydrophobic contacts',
#  'and does not appear to have well-defined structural features. In the',
#  'major right pathway (95% population, Fig. 3b→ d→ e), barnase Arg',
#  '59 interacts with barstar Glu 76, Asp 35, or both, in line with34,35.',
#  'Arg 59 may additionally form a hydrophobic contact with barstar',
#  'Trp 38. While no individual pair of residues is strongly formed in the',
#  'transition state22, Arg 59 is involved in 95% of all transition state con-',
#  'figurations. This observation confirms the pivotal role of Arg 59 inmed-',
#  'iating the binding transition34, and explains that Arg 59 mutants',
#  'reduced the binding rate by a factor of 10 (ref. 32). We expect that a',
#  'barstar double mutant of Glu 76 and Asp 35 will have a similar effect.',
#  '',
#  'The pre-bound state has a lifetime of about two microseconds',
#  '(Supplementary Fig. 2). In all binding events simulated, the',
#  'transition from the pre-bound to the loosely bound state trajectories',
#  'occurs within a single saving interval of our simulations, that is less',
#  'than 100 picoseconds. Thus the last step of docking into the barnase',
#  'binding pocket and forming the binding interface with its many',
#  'contacts is rare, but occurs quickly when it happens21,36. In line with',
#  'previous predictions22, the majority of the barnase–barstar short-',
#  'range interactions is formed after the transition state. In the limit of',
#  'low electrostatic interactions, the basal binding rate may be governed',
#  'by the bimolecular rate to form a ready-to-dock structure similar to',
#  'our pre-bound state22, and it is likely that the barrier of desolvation',
#  'and docking is reduced or even removed under these conditions.',
#  '',
#  'Conformational change in the complex. The bound states are in the',
#  'range of 5–12 kcal mol–1 more stable than intermediate, mis-bound',
#  'and pre-bound states and thus contain almost all of the equilibrium',
#  'population. We find two conformational substates in the bound',
#  'state: The loosely bound state with about 5% of the population',
#  'and an average heavy-atom RMSD to the crystal structure of',
#  '0.3 nm (Fig. 4a); and the tightly bound state with the remaining',
#  '95% of the population (Fig. 4b). The density of the tightly bound',
#  'state contains the crystal structure (Fig. 4c, average RMSD',
#  '0.21 nm), which is thus correctly predicted as the most stable state.',
#  '',
#  'Upon binding, the loosely bound state is reached first. This state',
#  'transitions into the tightly bound state within 5 µs on average, that',
#  'itself has an average lifetime of 130 µs before transitioning back to',
#  'the loosely bound state. These microsecond transitions occur',
#  'many times before the complex undergoes geminate rebinding',
#  '(Fig. 2g) or finally dissociates.',
#  '',
#  'Structurally, the native-state transition consists of a slight',
#  'rotation of barstar in the barnase binding pocket (compare',
#  'Fig. 4a,b). While both substates have similar residue contact patterns',
#  '(Supplementary Fig. 3), the most apparent difference is that the',
#  'barnase 35–41 loop is inserted between the barstar binding helix',
#  'and the large helix of barstar in the loosely bound state, while it is',
#  'inserted between the binding helix and binding loop in the tightly',
#  'bound state. The loosely bound state is stabilized by an interaction',
#  'between barnase Lys 27 (whose functional role is to stabilize the',
#  'phosphate group in the RNA substrate) and barstar Glu 80, while',
#  'the tightly bound state is stabilized by a salt bridge between',
#  'barnase Arg 83 and barstar Asp 39. Due to the latter salt bridge,',
#  'barnase loop 77–85 is stabilized in the tightly bound state, while it',
#  'is very flexible in the loosely bound state. Overall, the loosely bound',
#  'state is more flexible than the tightly bound state (compare Fig. 4a,b).',
#  '',
#  'These native substate dynamics may be observable experimen-',
#  'tally, for example, by fluorescence correlation microscopy or by',
#  '',
#  'a b',
#  '',
#  'c d',
#  '',
#  'e',
#  '',
#  'Arg 59',
#  'Asp 35',
#  '',
#  'Trp 38 Glu 76',
#  '',
#  'Gly 43',
#  'Trp 44',
#  '',
#  'Ala 37',
#  'Ser 38',
#  '',
#  '45° Late',
#  'intermediate 2',
#  '',
#  ' ',
#  '',
#  'Pre-bound',
#  '',
#  'Loosely',
#  'bound',
#  '',
#  '45°',
#  '',
#  'Figure 3 | Late steps in binding from late intermediates to the loosely',
#  'bound state. a,b, Two sets of structures of late intermediate state 2, shown',
#  'in 45° counterclockwise/clockwise rotation compared to Fig. 2d. c,d, Two',
#  'sets of structures of the pre-bound state. e, Loosely bound state. Grey clouds',
#  'show overlay of approximately 20 barstar conformations, sampled randomly',
#  'from the corresponding metastable states. Two binding pathways exist, in',
#  'which the binding domain of barstar interacts with barnase at its ‘left’ loop',
#  'around Ala 37 and Ser 38 (a,c), or at its ‘right’ loop (b,d), before docking into',
#  'the bound state (e). In the major pathway (b→ d→ e, approximately 95% of',
#  'the flux), barnase Arg 59 ‘anchors’ into barstar via Asp 35, Glu 76 (polar)',
#  'and Trp 38 (hydrophobic). Barstar can swing around barnase with the',
#  'anchor staying attached until final docking into the bound pose.',
#  '',
#  'ARTICLES NATURE CHEMISTRY DOI: 10.1038/NCHEM.2785',
#  '',
#  'NATURE CHEMISTRY | ADVANCE ONLINE PUBLICATION | www.nature.com/naturechemistry4',
#  '',
#  '© 2017 Macmillan Publishers Limited, part of Springer Nature. All rights reserved.',
#  '',
#  'http://dx.doi.org/10.1038/nchem.2785',
#  'http://www.nature.com/naturechemistry',
#  '',
#  '',
#  'fast temperature jump experiments that have been employed to',
#  'probe loose–tight binding transitions37. In particular, barstar Trp',
#  '44 changes solvent accessibility during the native substate transition,',
#  'rendering intrinsic tryptophan fluorescence a promising probe.',
#  '',
#  'Association kinetics of wild-type and a faster-associating mutant.',
#  'The very large association rate of barnase–barstar can be further',
#  'increased by specific mutations. To understand the microscopic',
#  'mechanisms of such perturbations, we conducted additional',
#  '0.3 milliseconds of MD simulations using the barnase mutant Glu',
#  '73 to Ala (E73A, see Methods), which associates a factor of 1.5–4',
#  'faster than the wild type23.',
#  '',
#  'As both the wild-type and the E73A HMM suffered from a',
#  'statistical bottleneck at the unbinding transition, the uncertain',
#  'transition rate from the loosely bound to pre-bound state was set',
#  'such that the models produce the experimentally known binding',
#  'free energy. The resulting consensus models still make independent',
#  'predictions of the binding rate and mechanism, while reproducing',
#  'experimental thermodynamics.',
#  '',
#  'TheE73Amodel predicts anassociation rate of 4 to 4.7 × 108 s–1M–1,',
#  'which correctly reflects an increase by a factor of 1.6–1.8 (ref. 23),',
#  'and can be explained by the increased electrostatic complementarity.',
#  'E73 does not participate in the binding interface, and indeed the',
#  'wild-type native complex structure is still predicted to be the most',
#  '',
#  '95%5%RMSD 0.3 nm',
#  'Lifetime 5 ms',
#  '',
#  'Tightly bound',
#  'RMSD 0.21 nm',
#  'Lifetime 130 ms',
#  '',
#  '1BRS',
#  'crystal structure ',
#  '',
#  'a b c',
#  '',
#  'Arg 83',
#  'Asp 39Lys 27',
#  '',
#  'Glu 80',
#  '',
#  'Trp 44',
#  'Trp 44',
#  '',
#  'Loosely bound',
#  '',
#  'Figure 4 | Native substate conformational dynamics. Native substates seen from ‘left’, that is, in a 90° clockwise rotation around the image vertical with',
#  'respect to Fig. 2d. a, Loosely bound state with lower population and higher structural flexibility. b, Tightly bound state with higher population and small',
#  'structural flexibility. c, Crystal structure 1BRS shown in the structural density of the tightly bound simulation state, for comparison with B. Grey cloud is',
#  'an overlay of approximately 20 barstar conformations, sampled randomly from the corresponding metastable states.',
#  '',
#  'Wild type E73A',
#  '',
#  'a b',
#  '',
#  'C',
#  'om',
#  '',
#  'm',
#  'itt',
#  '',
#  'or',
#  '',
#  '1',
#  '',
#  '0',
#  '',
#  '10–1 100 101 102 103 104',
#  '',
#  '0.5',
#  '',
#  'c d',
#  '',
#  'Loosely',
#  'bound',
#  '',
#  'Prebound',
#  '',
#  'Late intermediates',
#  '',
#  'Early intermediates',
#  '',
#  'Dissociated',
#  '',
#  'Misbound',
#  '',
#  'Tightly',
#  'bound',
#  '',
#  '1.0',
#  '0.8',
#  '0.6',
#  '0.4',
#  '0.2',
#  '0.0',
#  '',
#  'P',
#  'ro',
#  '',
#  'ba',
#  'bi',
#  '',
#  'lit',
#  'y',
#  '',
#  'Time (μs)',
#  '10–1 100 101 102 103 104',
#  '',
#  '1.0',
#  '0.8',
#  '0.6',
#  '0.4',
#  '0.2',
#  '0.0',
#  '',
#  'P',
#  'ro',
#  '',
#  'ba',
#  'bi',
#  '',
#  'lit',
#  'y',
#  '',
#  'Time (μs)',
#  '',
#  'Figure 5 | Comparison of kinetics between wild type and E73A mutant. a,b, Kinetic networks of the consensus models that are consistent with MD',
#  'simulation data and the experimental binding free energy. Network plots as in Fig. 2d, but the vertical position of states indicates the binding probability',
#  '(committor) and disc area is proportional to fourth root of state population. The E73A mutant shows a deeper funnel that leads to an increased association',
#  'rate. c,d, Kinetic evolution of probabilities when starting from dissociated state, computed from the HMM (see Supplementary Methods 4). Despite a higher',
#  'association rate, the E73A mutant takes longer to bind to the native state, as the increased association rate is due to rapid trapping in a mis-bound state that',
#  'is committed to further native binding. Colour scheme as in Fig. 2d.',
#  '',
#  'NATURE CHEMISTRY DOI: 10.1038/NCHEM.2785 ARTICLES',
#  '',
#  'NATURE CHEMISTRY | ADVANCE ONLINE PUBLICATION | www.nature.com/naturechemistry 5',
#  '',
#  '© 2017 Macmillan Publishers Limited, part of Springer Nature. All rights reserved.',
#  '',
#  'http://dx.doi.org/10.1038/nchem.2785',
#  'http://www.nature.com/naturechemistry',
#  '',
#  '',
#  'stable state in the mutant (Fig. 5b). Figure 5a,b shows kinetic',
#  'networks of the wild type and E73A mutant, similar to Fig. 2d but',
#  'with the y-positions indicating the probability of binding (committor)',
#  'of each state. Both systems are characterized by binding funnels,',
#  'that are broad on top but narrow down rapidly as the complex pro-',
#  'ceeds through late intermediates towards binding. The E73A funnel',
#  'is deeper in the sense that early intermediates have larger committor',
#  'probabilities, that is, it is more difficult to escape the complex, once',
#  'it is associated. E73A has a reduced stability of the bound state23.',
#  'The state that experiences the most profound increase of probability',
#  'is the mis-bound state. The time to form the native bound complex',
#  'is much longer in E73A compared to the wild type, as the system',
#  'gets trapped in the mis-bound state for 100s of microseconds',
#  '(Fig. 5d). An increase of the association rate does therefore not',
#  'necessarily imply more efficient binding in a functional sense.',
#  '',
#  'Based on the consensus models the experimental association rate',
#  'is simulated as a function of protein concentration. At micromolar',
#  'concentrations commonly used in experiments, the association rates',
#  'are linear in the concentration, that is, binding is limited by the',
#  'bimolecular encounter (Supplementary Fig. 5). In this condition',
#  'the dominant energy barrier is characterized by balancing the entro-',
#  'pic cost of bringing two molecules together at low concentration and',
#  'the onset of the electrostatic interactions. At concentrations of 10s to',
#  '100s of μM, this barrier disappears, the transition state of binding',
#  'becomes rate-limiting4, and we observe a concentration-independent',
#  'rate constant of 18,000 s–1 for the wild type and 1,500 s–1 for the E73A',
#  'mutant due to the transition state of binding (Supplementary Fig. 5).',
#  '',
#  'After an initial contact has been formed, the complex will',
#  'typically move through a sequence of other non-native inter-',
#  'mediates until it dissociates or proceeds to native binding with',
#  'about 50% probability each (Fig. 5a,b). The major bottleneck in',
#  'dissociation from the native state is the separation of the loosely',
#  'bound complex into the pre-bound, mis-bound and intermediate',
#  'states (Supplementary Fig. 6), from where the complex can dissociate',
#  'or perform geminate rebinding (Fig. 2g).',
#  '',
#  'Conclusion',
#  'By combining recent breakthroughs in simulation and analysis tech-',
#  'nology, we have demonstrated that a quantitatively accurate micro-',
#  'scopic model of protein–protein association can be obtained using',
#  'unbiased all-atom MD simulations and Markov modelling. This',
#  'model reveals kinetic and mechanistic details of the association mech-',
#  'anism and has enabled the discovery of previously unknown substates.',
#  '',
#  'The presented combination of simulation and analysis techniques',
#  'are applicable to any pair of macromolecules. While the available',
#  'computational power limits the size of the systems being studied to',
#  'currently a few hundred amino acids per protein, biological timescales',
#  'can be reached that are far beyond direct MD simulation times. This',
#  'opens the door to study how the parts of macromolecular assemblies',
#  'form, how viral and host proteins interact and how protein–DNA',
#  'interactions depend on DNA sequence and epigenetic modifications.',
#  '',
#  'Rather than a black-box model, the present approach provides',
#  'populations for every sampled atomistic structure and transition',
#  'rates between them. We have demonstrated that combining such an',
#  'extensive structural ensemble with an appropriate reweighting',
#  'method, the thermodynamics and kinetics of similar protein sequences',
#  'can bepredicted. In the future, protein sequences andpost-translational',
#  'modifications, or sequence and epigenetic modifications of interacting',
#  'nucleic acids can be designed to stabilize desirable intermediates,',
#  'change the kinetics or control the mechanism, with far-reaching',
#  'consequences for pharmaceutics, biotechnology andmaterial sciences.',
#  '',
#  'Methods',
#  'MD simulation setup. All-atom models of barnase wild type and barstar pseudo',
#  'wild type with C40,82A double mutation24 were constructed starting from crystal',
#  ...]

# %%
cont.splitlines()
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Complete protein-protein association kinetics in atomic detail revealed by molecular dynamics simulations and Markov modelling',
#  '',
#  '',
#  'Complete protein–protein association kinetics in',
#  'atomic detail revealed by molecular dynamics',
#  'simulations and Markov modelling',
#  'Nuria Plattner1*, Stefan Doerr2, Gianni De Fabritiis2,3 and Frank Noé1*',
#  '',
#  'Protein–protein association is fundamental to many life processes. However, a microscopic model describing the structures',
#  'and kinetics during association and dissociation is lacking on account of the long lifetimes of associated states, which have',
#  'prevented efficient sampling by direct molecular dynamics (MD) simulations. Here we demonstrate protein–protein',
#  'association and dissociation in atomistic resolution for the ribonuclease barnase and its inhibitor barstar by combining',
#  'adaptive high-throughput MD simulations and hidden Markov modelling. The model reveals experimentally consistent',
#  'intermediate structures, energetics and kinetics on timescales from microseconds to hours. A variety of flexibly attached',
#  'intermediates and misbound states funnel down to a transition state and a native basin consisting of the loosely bound',
#  'near-native state and the tightly bound crystallographic state. These results offer a deeper level of insight into',
#  'macromolecular recognition and our approach opens the door for understanding and manipulating a wide range of',
#  'macromolecular association processes.',
#  '',
#  'Life processes are critically dependent on the formation of bio-molecular complexes, and in particular, protein–protein associ-ation, which mediates the assembly of cellular structures, signal',
#  'transduction and inhibition, immune response and protein recruit-',
#  'ment to membrane scaffolds. Interactions of proteins with other',
#  'macromolecules also play key roles in applications such as inhibition',
#  'of protein activity by drugs1, gene editing2 and the assembly of',
#  'new materials3.',
#  '',
#  'A deep understanding of such processes and the ability to fully',
#  'plan and control their design would arise from a full map of the',
#  'conformation space of the interacting protein pairs. Such a micro-',
#  'scopic model would involve representative samples of all structures',
#  '(bound, dissociated, intermediates, etc.) in atomic resolution, their',
#  'equilibrium populations and the transition rates between them.',
#  '',
#  'However, such a complete microscopic picture has not yet been',
#  'achieved for protein–protein interaction. Experiments can probe',
#  'either individual aspects of the microscopic picture or averaged',
#  'ensembles, such as the most stable structures, association kinetics',
#  'and binding affinities. Mutational analyses can identify amino',
#  'acids stabilizing associated states or transition states4. The structure',
#  'of the transient encounter complex, that is, the set of structures',
#  'found immediately before the transition state of protein association,',
#  'has been probed using NMR5 and coarse-grained simulations6–9.',
#  'Binding free energies can be computed from atomistic simulations',
#  'when the bound pose is precisely known10, and the binding free',
#  'energy landscape can be reconstructed using metadynamics given',
#  'a set of pre-defined collective variables11. Inference of kinetics',
#  'then requires a kinetic model12 or additional unbiased simulations13.',
#  '',
#  'A candidate to reveal a complete microscopic model of protein–',
#  'protein interaction is unbiased atomic-detail molecular dynamics',
#  '(MD) simulation. Microscopic models of biomolecular processes',
#  'have recently been achieved due to combined advances in high-',
#  'performance computing and Markov modelling14–19. Previous',
#  'binding studies, however, have been limited to the association of',
#  '',
#  'small ligands to proteins and the co-folding of shorter peptide',
#  'chains16,19,20, or small parts of the association landscape such as',
#  'the downhill binding step from a pre-bound pose21. The simulation',
#  'of protein–protein association is challenged by the fact that',
#  'dissociation times exceed accessible MD simulation lengths by far,',
#  'such that long MD simulations will get stuck after a single',
#  'binding event, possibly even in non-native traps.',
#  '',
#  'Here we demonstrate how reversible protein–protein association',
#  'can be studied in atomistic detail by combining an extensive and',
#  'adaptively generated ensemble of unbiased molecular dynamics',
#  'simulations with hidden Markov modelling. We reproduce',
#  'measured structures, energetics and kinetics quantitatively and',
#  'obtain a full microscopic model of the protein complex structures,',
#  'thermodynamics and kinetics.',
#  '',
#  'Results and discussion',
#  'All-atom simulation of reversible protein–protein association. As',
#  'a prototypical example, we study the diffusion-limited association of',
#  'the experimentally well-characterized bacterial ribonuclease barnase',
#  'with its inhibitor barstar22,23. All-atom models of barnase wild type',
#  'and barstar pseudo wild type24 were immersed in a solvent box',
#  '(approximately 90,000 atoms). Several thousand unbiased molecular',
#  'dynamics (MD) simulations of 2 milliseconds aggregate length were',
#  'conducted in an automated high-throughput manner. These data',
#  'include 1.7 milliseconds of independent trajectories starting from',
#  'the dissociated state and 0.3 milliseconds in adaptive MD simulations.',
#  '',
#  'The adaptive MD launched periods of multiple parallel MD',
#  'trajectories, and the starting points of each period were selected so',
#  'as to favour the exploration of new states (Methods, Supplementary',
#  'Methods 1). This strategy can yield large speed-ups compared to',
#  'non-adaptive MD runs because slow processes with large energy',
#  'barriers are broken down into steps with individually smaller',
#  'barriers that can be sampled efficiently25–27 (Fig. 1a,b). When starting',
#  'from the dissociated state, both adaptive and non-adaptive',
#  '',
#  '1Department of Mathematics and Computer Science, Freie Universität Berlin, Arnimallee 6, 14195 Berlin, Germany. 2Computational Biophysics Laboratory',
#  '(GRIB-IMIM), Universitat Pompeu Fabra, Barcelona Biomedical Research Park (PRBB), C/ Doctor Aiguader 88, 08003 Barcelona, Spain. 3Institució Catalana',
#  'de Recerca i Estudis Avançats (ICREA), Passeig Lluis Companys 23, 08010 Barcelona, Spain. *e-mail: nuria.plattner@fu-berlin.de; frank.noe@fu-berlin.de',
#  '',
#  'ARTICLES',
#  'PUBLISHED ONLINE: 5 JUNE 2017 | DOI: 10.1038/NCHEM.2785',
#  '',
#  'NATURE CHEMISTRY | ADVANCE ONLINE PUBLICATION | www.nature.com/naturechemistry 1',
#  '',
#  '© 2017 Macmillan Publishers Limited, part of Springer Nature. All rights reserved.',
#  '',
#  'mailto:nuria.plattner@fu-berlin.de',
#  'mailto:frank.noe@fu-berlin.de',
#  'http://dx.doi.org/10.1038/nchem.2785',
#  'http://www.nature.com/naturechemistry',
#  '',
#  '',
#  'simulations reproducibly found the native bound complex. Adaptive',
#  'simulations required a total simulation effort of a few microseconds,',
#  'roughly an order of magnitude speed-up compared to an equilibrium',
#  'binding time of a tens of microseconds (Supplementary Fig. 1).',
#  'Surprisingly, the adaptive MD runs could also reproducibly reach',
#  'the dissociated state when starting from the crystal structure using',
#  'a total simulation effort of a few hundred microseconds, although',
#  'the expected dissociation time is hours (Supplementary Fig. 1).',
#  '',
#  'A first analysis shows that the total dataset contains several',
#  'thousand unspecific association and dissociation events, about 90',
#  'binding events from non-native associated states to native and 10',
#  'unbinding events (Fig. 1c).',
#  '',
#  'Equilibrium kinetics model and validation. Although the',
#  'individual simulations are not started from an equilibrium',
#  'distribution and are shorter than binding and dissociation',
#  'timescales, Markov modelling approaches can combine such a',
#  'trajectory ensemble towards unbiased equilibrium models of the',
#  'long-timescale kinetics and thermodynamics (Fig. 1a)28,29. Here, a',
#  'hidden Markov model (HMM) was built to estimate a network of',
#  '',
#  'states, associated protein structures, and transition rates30. The',
#  'HMM is coupled to a diffusive association model inspired by a',
#  'previous study31 in order to be able to predict concentration-',
#  'dependent association rates and binding free energies (Methods,',
#  'Supplementary Methods 3–7).',
#  '',
#  'As the data contains only a few unbinding events, the following',
#  'computed quantities have large uncertainties but are statistically',
#  'consistent with experiment, which will be exploited to compute',
#  'consensus models of experimental and simulation data (intervals',
#  'are 95% confidence): (i) binding free energy lies between 12 and',
#  '19 kcal mol–1 (experimental 16.8 kcal mol–1; see Supplementary',
#  'Methods 5), (ii) the dissociation rate lies in the range of 3 × 10–6',
#  '',
#  'to 1 × 10–1 s–1 (measurements lie in the range of 4.8 × 10–5 to',
#  '5.0 × 10–4 s–1; see Supplementary Methods 6).',
#  '',
#  'The model successfully predicts the following quantities: (iii)',
#  'crystal structure 1BRS is predicted to be the most stable state, and',
#  'the simulated structures assigned to it have an average RMSD of',
#  '0.21 nm to 1BRS, (iv) association rate is predicted to be 2.63 × 108',
#  '',
#  'to 2.65 × 108 s–1 M–1 (1 × 108 to 3.4 × 108 s–1 M–1 measured pre-',
#  'viously23,32), (v) using perturbation theory33, binding free energy',
#  'changes of 35 mutant sequences reported in23,32 were predicted',
#  'within statistical error (Fig. 2a and Supplementary Methods 9),',
#  '(vi) although this approach cannot compute absolute values of',
#  'association rates of mutants, the computed change in transition',
#  'state energy is an excellent predictor for the change in the experimental',
#  'on-rate (Fig. 2b).',
#  '',
#  'Overall binding mechanism. Having validated our model with a',
#  'large set of experimental data we proceeded to examine properties',
#  'that are more difficult to probe directly by experiments. Figure 2c,',
#  'd displays the overall mechanisms and structures found along the',
#  'binding pathways. The proteins initially associate to non-native',
#  '(large RMSD) states. At that point, they can dissociate and re-',
#  'associate or stay in contact and rearrange towards the native',
#  'complex (Fig. 2c–f ).',
#  '',
#  'At the high protein concentration in the simulation, initial',
#  'association occurs within tens of nanoseconds and with no detect-',
#  'able barrier. The initial association of barstar can occur at all',
#  'locations on the barnase surface. During the first microsecond,',
#  'the complex preferentially populates early intermediates with',
#  'barstar located opposite of the barnase binding site (orange states',
#  'in Fig. 2d). However, association can also occur directly into the',
#  'late intermediate and mis-bound states (blue/red states in Fig. 2d),',
#  'where barstar is located in or near the barnase binding groove,',
#  'but not in the native orientation. The preference for initially associ-',
#  'ating to locations away from the binding pocket can be explained by',
#  'the fact that these states cover a larger fraction of the surface. The',
#  'initial association preference depends on the salt concentration;',
#  'with enhanced steering to the binding site being expected when',
#  'charge screening is reduced7,22. Knocking out intermediate states',
#  'by removing them from the HMM showed that individual early',
#  'intermediates have no significant effect on the association rate,',
#  'and even removing all early intermediates only reduces the',
#  'association rate by 20% (Supplementary Table 2).',
#  '',
#  'On timescales of 1–10 µs, the population shifts toward the late',
#  'intermediates and mis-bound states (blue/red states in Figs 2d',
#  'and 5c), which have higher equilibrium populations than the',
#  'early intermediates. Of special interest is the mis-bound state',
#  '(red), that has barstar bound ‘upside down’. This state does not',
#  'have a well-defined binding interface, but a few non-native inter-',
#  'actions such as barnase Arg 83 or Arg 87 with barstar Glu 118',
#  'occur with significant probability (Supplementary Figs 3 and 4).',
#  'Intermediate states are kinetically well connected and have lifetimes',
#  'on the order of one microsecond each (Supplementary Fig. 2).',
#  'Removing the late intermediates would reduce the binding rate by',
#  'a factor of 2.5 (Supplementary Table 2)',
#  '',
#  '1 2',
#  '',
#  '3',
#  '4',
#  '',
#  '5 Sampling strategy ',
#  '',
#  'Markov model ',
#  '',
#  'Trajectories',
#  '',
#  'Tasks',
#  '',
#  'Data ',
#  'generation ',
#  '',
#  'Model building ',
#  '',
#  'Compute clusterClientba',
#  '',
#  'c',
#  '',
#  'AssociatedDissociated Bound',
#  '',
#  'Time (μs) Time (μs)',
#  '',
#  '2,867',
#  '',
#  'D',
#  'is',
#  '',
#  'ta',
#  'nc',
#  '',
#  'e ',
#  '(n',
#  '',
#  'm',
#  ')',
#  '',
#  'R',
#  'M',
#  '',
#  'S',
#  'D',
#  '',
#  ' (',
#  'nm',
#  '',
#  ')',
#  '',
#  '86',
#  '6',
#  '',
#  '0',
#  '0 0.5 0',
#  '',
#  '0',
#  '',
#  '1.5',
#  '',
#  '5',
#  '',
#  'Time (μs) Time (μs)',
#  '',
#  'R',
#  'M',
#  '',
#  'S',
#  'D',
#  '',
#  ' (',
#  'nm',
#  '',
#  ')',
#  '',
#  'D',
#  'is',
#  '',
#  'ta',
#  'nc',
#  '',
#  'e ',
#  '(n',
#  '',
#  'm',
#  ') 101,465',
#  '',
#  '6',
#  '',
#  '0',
#  '0 3.5 0 7',
#  '',
#  '0',
#  '',
#  '1.5',
#  '',
#  'Figure 1 | Simulation of protein–protein association and dissociation.',
#  'a, Scheme of a large-barrier process such as protein–protein dissociation that',
#  'can be subdivided into multiple steps. Such processes can be sampled by',
#  'combining adaptively seeded simulation trajectories between individual steps',
#  'via Markov modelling. b, Schematic outline of adaptive sampling process.',
#  'c, Total number of full association–dissociation and binding–unbinding',
#  'transitions evaluated by raw trajectory statistics of all barnase–barstar',
#  'simulation trajectories used subsequently. An association–dissociation',
#  'transition was counted when a trajectory moved from a state where the',
#  'proteins had a minimum distance between heavy atom pairs of >2 nm to',
#  '<0.3 nm, and vice versa. A binding–unbinding event was counted when a',
#  'trajectory moved from a state with minimum heavy-atom RMSD from the',
#  'crystallographic structure >1 nm to RMSD <0.3 nm, and vice versa. For each',
#  'trajectory only one count was made in order to avoid duplicate counting',
#  'of recrossing events. Three sample trajectory snippets are shown for each',
#  'type of transition.',
#  '',
#  'ARTICLES NATURE CHEMISTRY DOI: 10.1038/NCHEM.2785',
#  '',
#  'NATURE CHEMISTRY | ADVANCE ONLINE PUBLICATION | www.nature.com/naturechemistry2',
#  '',
#  '© 2017 Macmillan Publishers Limited, part of Springer Nature. All rights reserved.',
#  '',
#  'http://dx.doi.org/10.1038/nchem.2785',
#  'http://www.nature.com/naturechemistry',
#  '',
#  '',
#  'Misbound',
#  '',
#  'Early intermediates',
#  '',
#  'Late',
#  'intermediate 2',
#  '',
#  'Late',
#  'intermediate 1',
#  '',
#  'Pre-bound',
#  '',
#  'Loosely',
#  'bound',
#  '',
#  'Tightly',
#  'bound',
#  '',
#  'a',
#  '',
#  'd',
#  '',
#  'b c e',
#  '',
#  'f',
#  '',
#  'g',
#  '',
#  'Dissociated',
#  '',
#  'Association',
#  '',
#  'Binding',
#  '',
#  'Unbinding Rebinding',
#  '',
#  '12',
#  'ΔΔ',
#  '',
#  'G',
#  ' e',
#  '',
#  'xp',
#  'er',
#  '',
#  'im',
#  'en',
#  '',
#  't (',
#  'kc',
#  '',
#  'al',
#  ' m',
#  '',
#  'ol',
#  '–1',
#  '',
#  ')',
#  '',
#  '8',
#  '',
#  '4',
#  '',
#  '–4 0',
#  '',
#  'ΔΔG model (kcal mol–1)',
#  '',
#  '4 8 12',
#  '',
#  '–4',
#  '',
#  '0',
#  '',
#  '3',
#  '',
#  '2',
#  '',
#  '2',
#  '',
#  '0',
#  '',
#  'ΔΔ',
#  'G',
#  '',
#  'on',
#  ' e',
#  '',
#  'xp',
#  'er',
#  '',
#  'im',
#  'en',
#  '',
#  't (',
#  'kc',
#  '',
#  'al',
#  ' m',
#  '',
#  'ol',
#  '–1',
#  '',
#  ')',
#  '',
#  '–5 0 5 10',
#  '',
#  'ΔΔGTS model (kcal mol–1)',
#  '',
#  '–2',
#  '',
#  '–1 F',
#  're',
#  '',
#  'e ',
#  'en',
#  '',
#  'er',
#  'gy',
#  '',
#  ' (',
#  'kT',
#  '',
#  ')',
#  '',
#  'Minimal distance (nm)',
#  '',
#  '3.0 24',
#  '',
#  '21',
#  '',
#  '18',
#  '',
#  '15',
#  '',
#  '12',
#  '',
#  '9',
#  '',
#  '6',
#  '',
#  '3',
#  '',
#  '0',
#  '',
#  '2.5',
#  '',
#  '2.0',
#  '',
#  'R',
#  'M',
#  '',
#  'S',
#  'D',
#  '',
#  ' (',
#  'nm',
#  '',
#  ')',
#  '',
#  '0.3',
#  '0.2',
#  '0.1',
#  '',
#  '0.00 0.02 0.04 0.06 0.08 0.10',
#  '',
#  '5',
#  '',
#  't t+50 t+100 t+150 t+200',
#  '',
#  '10 15 20 25 30',
#  '',
#  '0.3',
#  '0.2',
#  '0.1',
#  '',
#  '0.3',
#  '0.2',
#  '0.1',
#  '',
#  'R',
#  'M',
#  '',
#  'S',
#  'D',
#  '',
#  ' (',
#  'nm',
#  '',
#  ')',
#  'R',
#  '',
#  'M',
#  'S',
#  '',
#  'D',
#  ' (',
#  '',
#  'nm',
#  ')',
#  '',
#  'R',
#  'M',
#  '',
#  'S',
#  'D',
#  '',
#  ' (',
#  'nm',
#  '',
#  ')',
#  '',
#  '1.5',
#  '',
#  '1.0',
#  '',
#  '0.5',
#  '',
#  '0.25 0.50 1.00 2.00 4.00',
#  '',
#  'Time (μs)',
#  '',
#  'Figure 2 | Kinetic model of barnase–barstar association. a,b, Comparison of experimental and predicted changes in binding free energies and association',
#  'rates for all 35 single and double alanine mutations from Table II of ref. 23 and Table I of ref. 32. Statistical confidence intervals of the model are indicated in',
#  'white (1-σ, 68% confidence) and grey (2-σ, 95% confidence). a, Changes in binding free energy (ΔΔG) are predicted within statistical error. b, Comparison',
#  'of the computed changes in barrier height of the binding transition with changes of apparent association transition state energy, computed as ΔΔGon,apparent',
#  '= –kBTln(kon',
#  '',
#  'mutant/kon',
#  'wt), where kBT= 0.598 kcal mol',
#  '',
#  '–1 and kon',
#  'mutant, kon',
#  '',
#  'wt are the experimental association rates of mutant and wild type, respectively. The model',
#  'prediction was computed as free energy difference between the pre-bound state as a proxy for the transition state, and all early intermediate, late',
#  'intermediate and mis-bound states. c, Free energy surface over protein–protein heavy atom minimal distance and minimal RMSD to the native complex.',
#  'Shown is a contour plot of –kTlnμ(x) evaluated for each trajectory sample x, where kT is the thermal energy and μ(x) is the equilibrium weight of each',
#  'sample computed by the HMM (see Supplementary Methods 4). d, Kinetic network between metastable states with lifetimes on the order of microseconds.',
#  'Only transition rate constants ≥0.2ms–1 are shown. Arrow thickness is proportional to rate constant, disc area is proportional to square root of state',
#  'population. Structures are centered on barnase (orange) with its binding groove on top and its N-terminal helix on the bottom. Barstar is shown in grey with',
#  'its binding domain in green. Grey clouds show overlay of approximately 20 barstar conformations, sampled randomly from the corresponding metastable',
#  'states. e–g, Minimal RMSD to crystallographic complex shown for sample trajectories generated from the HMM (see Supplementary Methods 4). Initial',
#  'association (e), binding to the native complex (f), and geminate rebinding after being bound for a long time t (one hour on average; g).',
#  '',
#  'NATURE CHEMISTRY DOI: 10.1038/NCHEM.2785 ARTICLES',
#  '',
#  'NATURE CHEMISTRY | ADVANCE ONLINE PUBLICATION | www.nature.com/naturechemistry 3',
#  '',
#  '© 2017 Macmillan Publishers Limited, part of Springer Nature. All rights reserved.',
#  '',
#  'http://dx.doi.org/10.1038/nchem.2785',
#  'http://www.nature.com/naturechemistry',
#  '',
#  '',
#  'On timescales of 10–100 µs, the complex passes through a',
#  'pre-bound state (magenta in Figs 2d and 5c) and then continues',
#  'to the natively bound complex (grey states in Figs 2d and 5c),',
#  'which consists of a loosely bound and a tightly bound substate',
#  'that exchange on the microsecond timescale.',
#  '',
#  'Nature of the transition state of binding. The kinetic bottleneck',
#  'between the intermediate states and natively bound states is the',
#  'mandatory passage through the pre-bound state (magenta in Fig. 2d),',
#  'that is hence an on-pathway intermediate. Both the transition into',
#  'the pre-bound state and the binding from the pre-bound state',
#  'involve barriers (Supplementary Fig. 6). We refer to these barriers',
#  'collectively as transition state of binding as they are rate-limiting at',
#  'sufficiently high protein concentrations (Supplementary Fig. 5).',
#  '',
#  'The transition from the late intermediates through the pre-bound',
#  'state into the loosely bound state is characterized by two microscopic',
#  'pathways, in which barstar interacts with either of the two barnase',
#  'loops surrounding the binding groove: the ‘left’ loop including Ser',
#  '',
#  '38 and the ‘right’ RNA recognition loop of barnase including Arg',
#  '59 (Fig. 3) whose importance for steering of the two protein has',
#  'been shown before6,7. Due to the flexibility of both loop regions,',
#  'barstar can “swing” around its attachment point, giving rise to a',
#  'quite flexible set of structures. These pathways are not separated by',
#  'significant barriers, i.e. the complex can change between “left” and',
#  '“right” attachment point multiple times before binding.',
#  '',
#  'The minor left pathway (5% population, Fig. 3a→ c→ e) involves',
#  'different possible protein contacts, including hydrophobic contacts',
#  'and does not appear to have well-defined structural features. In the',
#  'major right pathway (95% population, Fig. 3b→ d→ e), barnase Arg',
#  '59 interacts with barstar Glu 76, Asp 35, or both, in line with34,35.',
#  'Arg 59 may additionally form a hydrophobic contact with barstar',
#  'Trp 38. While no individual pair of residues is strongly formed in the',
#  'transition state22, Arg 59 is involved in 95% of all transition state con-',
#  'figurations. This observation confirms the pivotal role of Arg 59 inmed-',
#  'iating the binding transition34, and explains that Arg 59 mutants',
#  'reduced the binding rate by a factor of 10 (ref. 32). We expect that a',
#  'barstar double mutant of Glu 76 and Asp 35 will have a similar effect.',
#  '',
#  'The pre-bound state has a lifetime of about two microseconds',
#  '(Supplementary Fig. 2). In all binding events simulated, the',
#  'transition from the pre-bound to the loosely bound state trajectories',
#  'occurs within a single saving interval of our simulations, that is less',
#  'than 100 picoseconds. Thus the last step of docking into the barnase',
#  'binding pocket and forming the binding interface with its many',
#  'contacts is rare, but occurs quickly when it happens21,36. In line with',
#  'previous predictions22, the majority of the barnase–barstar short-',
#  'range interactions is formed after the transition state. In the limit of',
#  'low electrostatic interactions, the basal binding rate may be governed',
#  'by the bimolecular rate to form a ready-to-dock structure similar to',
#  'our pre-bound state22, and it is likely that the barrier of desolvation',
#  'and docking is reduced or even removed under these conditions.',
#  '',
#  'Conformational change in the complex. The bound states are in the',
#  'range of 5–12 kcal mol–1 more stable than intermediate, mis-bound',
#  'and pre-bound states and thus contain almost all of the equilibrium',
#  'population. We find two conformational substates in the bound',
#  'state: The loosely bound state with about 5% of the population',
#  'and an average heavy-atom RMSD to the crystal structure of',
#  '0.3 nm (Fig. 4a); and the tightly bound state with the remaining',
#  '95% of the population (Fig. 4b). The density of the tightly bound',
#  'state contains the crystal structure (Fig. 4c, average RMSD',
#  '0.21 nm), which is thus correctly predicted as the most stable state.',
#  '',
#  'Upon binding, the loosely bound state is reached first. This state',
#  'transitions into the tightly bound state within 5 µs on average, that',
#  'itself has an average lifetime of 130 µs before transitioning back to',
#  'the loosely bound state. These microsecond transitions occur',
#  'many times before the complex undergoes geminate rebinding',
#  '(Fig. 2g) or finally dissociates.',
#  '',
#  'Structurally, the native-state transition consists of a slight',
#  'rotation of barstar in the barnase binding pocket (compare',
#  'Fig. 4a,b). While both substates have similar residue contact patterns',
#  '(Supplementary Fig. 3), the most apparent difference is that the',
#  'barnase 35–41 loop is inserted between the barstar binding helix',
#  'and the large helix of barstar in the loosely bound state, while it is',
#  'inserted between the binding helix and binding loop in the tightly',
#  'bound state. The loosely bound state is stabilized by an interaction',
#  'between barnase Lys 27 (whose functional role is to stabilize the',
#  'phosphate group in the RNA substrate) and barstar Glu 80, while',
#  'the tightly bound state is stabilized by a salt bridge between',
#  'barnase Arg 83 and barstar Asp 39. Due to the latter salt bridge,',
#  'barnase loop 77–85 is stabilized in the tightly bound state, while it',
#  'is very flexible in the loosely bound state. Overall, the loosely bound',
#  'state is more flexible than the tightly bound state (compare Fig. 4a,b).',
#  '',
#  'These native substate dynamics may be observable experimen-',
#  'tally, for example, by fluorescence correlation microscopy or by',
#  '',
#  'a b',
#  '',
#  'c d',
#  '',
#  'e',
#  '',
#  'Arg 59',
#  'Asp 35',
#  '',
#  'Trp 38 Glu 76',
#  '',
#  'Gly 43',
#  'Trp 44',
#  '',
#  'Ala 37',
#  'Ser 38',
#  '',
#  '45° Late',
#  'intermediate 2',
#  '',
#  ' ',
#  '',
#  'Pre-bound',
#  '',
#  'Loosely',
#  'bound',
#  '',
#  '45°',
#  '',
#  'Figure 3 | Late steps in binding from late intermediates to the loosely',
#  'bound state. a,b, Two sets of structures of late intermediate state 2, shown',
#  'in 45° counterclockwise/clockwise rotation compared to Fig. 2d. c,d, Two',
#  'sets of structures of the pre-bound state. e, Loosely bound state. Grey clouds',
#  'show overlay of approximately 20 barstar conformations, sampled randomly',
#  'from the corresponding metastable states. Two binding pathways exist, in',
#  'which the binding domain of barstar interacts with barnase at its ‘left’ loop',
#  'around Ala 37 and Ser 38 (a,c), or at its ‘right’ loop (b,d), before docking into',
#  'the bound state (e). In the major pathway (b→ d→ e, approximately 95% of',
#  'the flux), barnase Arg 59 ‘anchors’ into barstar via Asp 35, Glu 76 (polar)',
#  'and Trp 38 (hydrophobic). Barstar can swing around barnase with the',
#  'anchor staying attached until final docking into the bound pose.',
#  '',
#  'ARTICLES NATURE CHEMISTRY DOI: 10.1038/NCHEM.2785',
#  '',
#  'NATURE CHEMISTRY | ADVANCE ONLINE PUBLICATION | www.nature.com/naturechemistry4',
#  '',
#  '© 2017 Macmillan Publishers Limited, part of Springer Nature. All rights reserved.',
#  '',
#  'http://dx.doi.org/10.1038/nchem.2785',
#  'http://www.nature.com/naturechemistry',
#  '',
#  '',
#  'fast temperature jump experiments that have been employed to',
#  'probe loose–tight binding transitions37. In particular, barstar Trp',
#  '44 changes solvent accessibility during the native substate transition,',
#  'rendering intrinsic tryptophan fluorescence a promising probe.',
#  '',
#  'Association kinetics of wild-type and a faster-associating mutant.',
#  'The very large association rate of barnase–barstar can be further',
#  'increased by specific mutations. To understand the microscopic',
#  'mechanisms of such perturbations, we conducted additional',
#  '0.3 milliseconds of MD simulations using the barnase mutant Glu',
#  '73 to Ala (E73A, see Methods), which associates a factor of 1.5–4',
#  'faster than the wild type23.',
#  '',
#  'As both the wild-type and the E73A HMM suffered from a',
#  'statistical bottleneck at the unbinding transition, the uncertain',
#  'transition rate from the loosely bound to pre-bound state was set',
#  'such that the models produce the experimentally known binding',
#  'free energy. The resulting consensus models still make independent',
#  'predictions of the binding rate and mechanism, while reproducing',
#  'experimental thermodynamics.',
#  '',
#  'TheE73Amodel predicts anassociation rate of 4 to 4.7 × 108 s–1M–1,',
#  'which correctly reflects an increase by a factor of 1.6–1.8 (ref. 23),',
#  'and can be explained by the increased electrostatic complementarity.',
#  'E73 does not participate in the binding interface, and indeed the',
#  'wild-type native complex structure is still predicted to be the most',
#  '',
#  '95%5%RMSD 0.3 nm',
#  'Lifetime 5 ms',
#  '',
#  'Tightly bound',
#  'RMSD 0.21 nm',
#  'Lifetime 130 ms',
#  '',
#  '1BRS',
#  'crystal structure ',
#  '',
#  'a b c',
#  '',
#  'Arg 83',
#  'Asp 39Lys 27',
#  '',
#  'Glu 80',
#  '',
#  'Trp 44',
#  'Trp 44',
#  '',
#  'Loosely bound',
#  '',
#  'Figure 4 | Native substate conformational dynamics. Native substates seen from ‘left’, that is, in a 90° clockwise rotation around the image vertical with',
#  'respect to Fig. 2d. a, Loosely bound state with lower population and higher structural flexibility. b, Tightly bound state with higher population and small',
#  'structural flexibility. c, Crystal structure 1BRS shown in the structural density of the tightly bound simulation state, for comparison with B. Grey cloud is',
#  'an overlay of approximately 20 barstar conformations, sampled randomly from the corresponding metastable states.',
#  '',
#  'Wild type E73A',
#  '',
#  'a b',
#  '',
#  'C',
#  'om',
#  '',
#  'm',
#  'itt',
#  '',
#  'or',
#  '',
#  '1',
#  '',
#  '0',
#  '',
#  '10–1 100 101 102 103 104',
#  '',
#  '0.5',
#  '',
#  'c d',
#  '',
#  'Loosely',
#  'bound',
#  '',
#  'Prebound',
#  '',
#  'Late intermediates',
#  '',
#  'Early intermediates',
#  '',
#  'Dissociated',
#  '',
#  'Misbound',
#  '',
#  'Tightly',
#  'bound',
#  '',
#  '1.0',
#  '0.8',
#  '0.6',
#  '0.4',
#  '0.2',
#  '0.0',
#  '',
#  'P',
#  'ro',
#  '',
#  'ba',
#  'bi',
#  '',
#  'lit',
#  'y',
#  '',
#  'Time (μs)',
#  '10–1 100 101 102 103 104',
#  '',
#  '1.0',
#  '0.8',
#  '0.6',
#  '0.4',
#  '0.2',
#  '0.0',
#  '',
#  'P',
#  'ro',
#  '',
#  'ba',
#  'bi',
#  '',
#  'lit',
#  'y',
#  '',
#  'Time (μs)',
#  '',
#  'Figure 5 | Comparison of kinetics between wild type and E73A mutant. a,b, Kinetic networks of the consensus models that are consistent with MD',
#  'simulation data and the experimental binding free energy. Network plots as in Fig. 2d, but the vertical position of states indicates the binding probability',
#  '(committor) and disc area is proportional to fourth root of state population. The E73A mutant shows a deeper funnel that leads to an increased association',
#  'rate. c,d, Kinetic evolution of probabilities when starting from dissociated state, computed from the HMM (see Supplementary Methods 4). Despite a higher',
#  'association rate, the E73A mutant takes longer to bind to the native state, as the increased association rate is due to rapid trapping in a mis-bound state that',
#  'is committed to further native binding. Colour scheme as in Fig. 2d.',
#  '',
#  'NATURE CHEMISTRY DOI: 10.1038/NCHEM.2785 ARTICLES',
#  '',
#  'NATURE CHEMISTRY | ADVANCE ONLINE PUBLICATION | www.nature.com/naturechemistry 5',
#  '',
#  '© 2017 Macmillan Publishers Limited, part of Springer Nature. All rights reserved.',
#  '',
#  'http://dx.doi.org/10.1038/nchem.2785',
#  'http://www.nature.com/naturechemistry',
#  '',
#  '',
#  'stable state in the mutant (Fig. 5b). Figure 5a,b shows kinetic',
#  'networks of the wild type and E73A mutant, similar to Fig. 2d but',
#  'with the y-positions indicating the probability of binding (committor)',
#  'of each state. Both systems are characterized by binding funnels,',
#  'that are broad on top but narrow down rapidly as the complex pro-',
#  'ceeds through late intermediates towards binding. The E73A funnel',
#  'is deeper in the sense that early intermediates have larger committor',
#  'probabilities, that is, it is more difficult to escape the complex, once',
#  'it is associated. E73A has a reduced stability of the bound state23.',
#  'The state that experiences the most profound increase of probability',
#  'is the mis-bound state. The time to form the native bound complex',
#  'is much longer in E73A compared to the wild type, as the system',
#  'gets trapped in the mis-bound state for 100s of microseconds',
#  '(Fig. 5d). An increase of the association rate does therefore not',
#  'necessarily imply more efficient binding in a functional sense.',
#  '',
#  'Based on the consensus models the experimental association rate',
#  'is simulated as a function of protein concentration. At micromolar',
#  'concentrations commonly used in experiments, the association rates',
#  'are linear in the concentration, that is, binding is limited by the',
#  'bimolecular encounter (Supplementary Fig. 5). In this condition',
#  'the dominant energy barrier is characterized by balancing the entro-',
#  'pic cost of bringing two molecules together at low concentration and',
#  'the onset of the electrostatic interactions. At concentrations of 10s to',
#  '100s of μM, this barrier disappears, the transition state of binding',
#  'becomes rate-limiting4, and we observe a concentration-independent',
#  'rate constant of 18,000 s–1 for the wild type and 1,500 s–1 for the E73A',
#  'mutant due to the transition state of binding (Supplementary Fig. 5).',
#  '',
#  'After an initial contact has been formed, the complex will',
#  'typically move through a sequence of other non-native inter-',
#  'mediates until it dissociates or proceeds to native binding with',
#  'about 50% probability each (Fig. 5a,b). The major bottleneck in',
#  'dissociation from the native state is the separation of the loosely',
#  'bound complex into the pre-bound, mis-bound and intermediate',
#  'states (Supplementary Fig. 6), from where the complex can dissociate',
#  'or perform geminate rebinding (Fig. 2g).',
#  '',
#  'Conclusion',
#  'By combining recent breakthroughs in simulation and analysis tech-',
#  'nology, we have demonstrated that a quantitatively accurate micro-',
#  'scopic model of protein–protein association can be obtained using',
#  'unbiased all-atom MD simulations and Markov modelling. This',
#  'model reveals kinetic and mechanistic details of the association mech-',
#  'anism and has enabled the discovery of previously unknown substates.',
#  '',
#  'The presented combination of simulation and analysis techniques',
#  'are applicable to any pair of macromolecules. While the available',
#  'computational power limits the size of the systems being studied to',
#  'currently a few hundred amino acids per protein, biological timescales',
#  'can be reached that are far beyond direct MD simulation times. This',
#  'opens the door to study how the parts of macromolecular assemblies',
#  'form, how viral and host proteins interact and how protein–DNA',
#  'interactions depend on DNA sequence and epigenetic modifications.',
#  '',
#  'Rather than a black-box model, the present approach provides',
#  'populations for every sampled atomistic structure and transition',
#  'rates between them. We have demonstrated that combining such an',
#  'extensive structural ensemble with an appropriate reweighting',
#  'method, the thermodynamics and kinetics of similar protein sequences',
#  'can bepredicted. In the future, protein sequences andpost-translational',
#  'modifications, or sequence and epigenetic modifications of interacting',
#  'nucleic acids can be designed to stabilize desirable intermediates,',
#  'change the kinetics or control the mechanism, with far-reaching',
#  'consequences for pharmaceutics, biotechnology andmaterial sciences.',
#  '',
#  'Methods',
#  'MD simulation setup. All-atom models of barnase wild type and barstar pseudo',
#  'wild type with C40,82A double mutation24 were constructed starting from crystal',
#  ...]

# %%
meth = cont.partition('Fabritiis')

# %%
meth[0]
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nComplete protein-protein association kinetics in atomic detail revealed by molecular dynamics simulations and Markov modelling\n\n\nComplete protein–protein association kinetics in\natomic detail revealed by molecular dynamics\nsimulations and Markov modelling\nNuria Plattner1*, Stefan Doerr2, Gianni De '

# %% [markdown]
# ## Process Text with Natural Language Toolkit

# %%
import nltk

# %%
sentence = cont

# %%
tokens = nltk.word_tokenize(sentence)

# %%
tokens
# Out:
# ['Complete',
#  'protein-protein',
#  'association',
#  'kinetics',
#  'in',
#  'atomic',
#  'detail',
#  'revealed',
#  'by',
#  'molecular',
#  'dynamics',
#  'simulations',
#  'and',
#  'Markov',
#  'modelling',
#  'Complete',
#  'protein–protein',
#  'association',
#  'kinetics',
#  'in',
#  'atomic',
#  'detail',
#  'revealed',
#  'by',
#  'molecular',
#  'dynamics',
#  'simulations',
#  'and',
#  'Markov',
#  'modelling',
#  'Nuria',
#  'Plattner1*',
#  ',',
#  'Stefan',
#  'Doerr2',
#  ',',
#  'Gianni',
#  'De',
#  'Fabritiis2,3',
#  'and',
#  'Frank',
#  'Noé1*',
#  'Protein–protein',
#  'association',
#  'is',
#  'fundamental',
#  'to',
#  'many',
#  'life',
#  'processes',
#  '.',
#  'However',
#  ',',
#  'a',
#  'microscopic',
#  'model',
#  'describing',
#  'the',
#  'structures',
#  'and',
#  'kinetics',
#  'during',
#  'association',
#  'and',
#  'dissociation',
#  'is',
#  'lacking',
#  'on',
#  'account',
#  'of',
#  'the',
#  'long',
#  'lifetimes',
#  'of',
#  'associated',
#  'states',
#  ',',
#  'which',
#  'have',
#  'prevented',
#  'efficient',
#  'sampling',
#  'by',
#  'direct',
#  'molecular',
#  'dynamics',
#  '(',
#  'MD',
#  ')',
#  'simulations',
#  '.',
#  'Here',
#  'we',
#  'demonstrate',
#  'protein–protein',
#  'association',
#  'and',
#  'dissociation',
#  'in',
#  'atomistic',
#  'resolution',
#  'for',
#  'the',
#  'ribonuclease',
#  'barnase',
#  'and',
#  'its',
#  'inhibitor',
#  'barstar',
#  'by',
#  'combining',
#  'adaptive',
#  'high-throughput',
#  'MD',
#  'simulations',
#  'and',
#  'hidden',
#  'Markov',
#  'modelling',
#  '.',
#  'The',
#  'model',
#  'reveals',
#  'experimentally',
#  'consistent',
#  'intermediate',
#  'structures',
#  ',',
#  'energetics',
#  'and',
#  'kinetics',
#  'on',
#  'timescales',
#  'from',
#  'microseconds',
#  'to',
#  'hours',
#  '.',
#  'A',
#  'variety',
#  'of',
#  'flexibly',
#  'attached',
#  'intermediates',
#  'and',
#  'misbound',
#  'states',
#  'funnel',
#  'down',
#  'to',
#  'a',
#  'transition',
#  'state',
#  'and',
#  'a',
#  'native',
#  'basin',
#  'consisting',
#  'of',
#  'the',
#  'loosely',
#  'bound',
#  'near-native',
#  'state',
#  'and',
#  'the',
#  'tightly',
#  'bound',
#  'crystallographic',
#  'state',
#  '.',
#  'These',
#  'results',
#  'offer',
#  'a',
#  'deeper',
#  'level',
#  'of',
#  'insight',
#  'into',
#  'macromolecular',
#  'recognition',
#  'and',
#  'our',
#  'approach',
#  'opens',
#  'the',
#  'door',
#  'for',
#  'understanding',
#  'and',
#  'manipulating',
#  'a',
#  'wide',
#  'range',
#  'of',
#  'macromolecular',
#  'association',
#  'processes',
#  '.',
#  'Life',
#  'processes',
#  'are',
#  'critically',
#  'dependent',
#  'on',
#  'the',
#  'formation',
#  'of',
#  'bio-molecular',
#  'complexes',
#  ',',
#  'and',
#  'in',
#  'particular',
#  ',',
#  'protein–protein',
#  'associ-ation',
#  ',',
#  'which',
#  'mediates',
#  'the',
#  'assembly',
#  'of',
#  'cellular',
#  'structures',
#  ',',
#  'signal',
#  'transduction',
#  'and',
#  'inhibition',
#  ',',
#  'immune',
#  'response',
#  'and',
#  'protein',
#  'recruit-',
#  'ment',
#  'to',
#  'membrane',
#  'scaffolds',
#  '.',
#  'Interactions',
#  'of',
#  'proteins',
#  'with',
#  'other',
#  'macromolecules',
#  'also',
#  'play',
#  'key',
#  'roles',
#  'in',
#  'applications',
#  'such',
#  'as',
#  'inhibition',
#  'of',
#  'protein',
#  'activity',
#  'by',
#  'drugs1',
#  ',',
#  'gene',
#  'editing2',
#  'and',
#  'the',
#  'assembly',
#  'of',
#  'new',
#  'materials3',
#  '.',
#  'A',
#  'deep',
#  'understanding',
#  'of',
#  'such',
#  'processes',
#  'and',
#  'the',
#  'ability',
#  'to',
#  'fully',
#  'plan',
#  'and',
#  'control',
#  'their',
#  'design',
#  'would',
#  'arise',
#  'from',
#  'a',
#  'full',
#  'map',
#  'of',
#  'the',
#  'conformation',
#  'space',
#  'of',
#  'the',
#  'interacting',
#  'protein',
#  'pairs',
#  '.',
#  'Such',
#  'a',
#  'micro-',
#  'scopic',
#  'model',
#  'would',
#  'involve',
#  'representative',
#  'samples',
#  'of',
#  'all',
#  'structures',
#  '(',
#  'bound',
#  ',',
#  'dissociated',
#  ',',
#  'intermediates',
#  ',',
#  'etc',
#  '.',
#  ')',
#  'in',
#  'atomic',
#  'resolution',
#  ',',
#  'their',
#  'equilibrium',
#  'populations',
#  'and',
#  'the',
#  'transition',
#  'rates',
#  'between',
#  'them',
#  '.',
#  'However',
#  ',',
#  'such',
#  'a',
#  'complete',
#  'microscopic',
#  'picture',
#  'has',
#  'not',
#  'yet',
#  'been',
#  'achieved',
#  'for',
#  'protein–protein',
#  'interaction',
#  '.',
#  'Experiments',
#  'can',
#  'probe',
#  'either',
#  'individual',
#  'aspects',
#  'of',
#  'the',
#  'microscopic',
#  'picture',
#  'or',
#  'averaged',
#  'ensembles',
#  ',',
#  'such',
#  'as',
#  'the',
#  'most',
#  'stable',
#  'structures',
#  ',',
#  'association',
#  'kinetics',
#  'and',
#  'binding',
#  'affinities',
#  '.',
#  'Mutational',
#  'analyses',
#  'can',
#  'identify',
#  'amino',
#  'acids',
#  'stabilizing',
#  'associated',
#  'states',
#  'or',
#  'transition',
#  'states4',
#  '.',
#  'The',
#  'structure',
#  'of',
#  'the',
#  'transient',
#  'encounter',
#  'complex',
#  ',',
#  'that',
#  'is',
#  ',',
#  'the',
#  'set',
#  'of',
#  'structures',
#  'found',
#  'immediately',
#  'before',
#  'the',
#  'transition',
#  'state',
#  'of',
#  'protein',
#  'association',
#  ',',
#  'has',
#  'been',
#  'probed',
#  'using',
#  'NMR5',
#  'and',
#  'coarse-grained',
#  'simulations6–9',
#  '.',
#  'Binding',
#  'free',
#  'energies',
#  'can',
#  'be',
#  'computed',
#  'from',
#  'atomistic',
#  'simulations',
#  'when',
#  'the',
#  'bound',
#  'pose',
#  'is',
#  'precisely',
#  'known10',
#  ',',
#  'and',
#  'the',
#  'binding',
#  'free',
#  'energy',
#  'landscape',
#  'can',
#  'be',
#  'reconstructed',
#  'using',
#  'metadynamics',
#  'given',
#  'a',
#  'set',
#  'of',
#  'pre-defined',
#  'collective',
#  'variables11',
#  '.',
#  'Inference',
#  'of',
#  'kinetics',
#  'then',
#  'requires',
#  'a',
#  'kinetic',
#  'model12',
#  'or',
#  'additional',
#  'unbiased',
#  'simulations13',
#  '.',
#  'A',
#  'candidate',
#  'to',
#  'reveal',
#  'a',
#  'complete',
#  'microscopic',
#  'model',
#  'of',
#  'protein–',
#  'protein',
#  'interaction',
#  'is',
#  'unbiased',
#  'atomic-detail',
#  'molecular',
#  'dynamics',
#  '(',
#  'MD',
#  ')',
#  'simulation',
#  '.',
#  'Microscopic',
#  'models',
#  'of',
#  'biomolecular',
#  'processes',
#  'have',
#  'recently',
#  'been',
#  'achieved',
#  'due',
#  'to',
#  'combined',
#  'advances',
#  'in',
#  'high-',
#  'performance',
#  'computing',
#  'and',
#  'Markov',
#  'modelling14–19',
#  '.',
#  'Previous',
#  'binding',
#  'studies',
#  ',',
#  'however',
#  ',',
#  'have',
#  'been',
#  'limited',
#  'to',
#  'the',
#  'association',
#  'of',
#  'small',
#  'ligands',
#  'to',
#  'proteins',
#  'and',
#  'the',
#  'co-folding',
#  'of',
#  'shorter',
#  'peptide',
#  'chains16,19,20',
#  ',',
#  'or',
#  'small',
#  'parts',
#  'of',
#  'the',
#  'association',
#  'landscape',
#  'such',
#  'as',
#  'the',
#  'downhill',
#  'binding',
#  'step',
#  'from',
#  'a',
#  'pre-bound',
#  'pose21',
#  '.',
#  'The',
#  'simulation',
#  'of',
#  'protein–protein',
#  'association',
#  'is',
#  'challenged',
#  'by',
#  'the',
#  'fact',
#  'that',
#  'dissociation',
#  'times',
#  'exceed',
#  'accessible',
#  'MD',
#  'simulation',
#  'lengths',
#  'by',
#  'far',
#  ',',
#  'such',
#  'that',
#  'long',
#  'MD',
#  'simulations',
#  'will',
#  'get',
#  'stuck',
#  'after',
#  'a',
#  'single',
#  'binding',
#  'event',
#  ',',
#  'possibly',
#  'even',
#  'in',
#  'non-native',
#  'traps',
#  '.',
#  'Here',
#  'we',
#  'demonstrate',
#  'how',
#  'reversible',
#  'protein–protein',
#  'association',
#  'can',
#  'be',
#  'studied',
#  'in',
#  'atomistic',
#  'detail',
#  'by',
#  'combining',
#  'an',
#  'extensive',
#  'and',
#  'adaptively',
#  'generated',
#  'ensemble',
#  'of',
#  'unbiased',
#  'molecular',
#  'dynamics',
#  'simulations',
#  'with',
#  'hidden',
#  'Markov',
#  'modelling',
#  '.',
#  'We',
#  'reproduce',
#  'measured',
#  'structures',
#  ',',
#  'energetics',
#  'and',
#  'kinetics',
#  'quantitatively',
#  'and',
#  'obtain',
#  'a',
#  'full',
#  'microscopic',
#  'model',
#  'of',
#  'the',
#  'protein',
#  'complex',
#  'structures',
#  ',',
#  'thermodynamics',
#  'and',
#  'kinetics',
#  '.',
#  'Results',
#  'and',
#  'discussion',
#  'All-atom',
#  'simulation',
#  'of',
#  'reversible',
#  'protein–protein',
#  'association',
#  '.',
#  'As',
#  'a',
#  'prototypical',
#  'example',
#  ',',
#  'we',
#  'study',
#  'the',
#  'diffusion-limited',
#  'association',
#  'of',
#  'the',
#  'experimentally',
#  'well-characterized',
#  'bacterial',
#  'ribonuclease',
#  'barnase',
#  'with',
#  'its',
#  'inhibitor',
#  'barstar22,23',
#  '.',
#  'All-atom',
#  'models',
#  'of',
#  'barnase',
#  'wild',
#  'type',
#  'and',
#  'barstar',
#  'pseudo',
#  'wild',
#  'type24',
#  'were',
#  'immersed',
#  'in',
#  'a',
#  'solvent',
#  'box',
#  '(',
#  'approximately',
#  '90,000',
#  'atoms',
#  ')',
#  '.',
#  'Several',
#  'thousand',
#  'unbiased',
#  'molecular',
#  'dynamics',
#  '(',
#  'MD',
#  ')',
#  'simulations',
#  'of',
#  '2',
#  'milliseconds',
#  'aggregate',
#  'length',
#  'were',
#  'conducted',
#  'in',
#  'an',
#  'automated',
#  'high-throughput',
#  'manner',
#  '.',
#  'These',
#  'data',
#  'include',
#  '1.7',
#  'milliseconds',
#  'of',
#  'independent',
#  'trajectories',
#  'starting',
#  'from',
#  'the',
#  'dissociated',
#  'state',
#  'and',
#  '0.3',
#  'milliseconds',
#  'in',
#  'adaptive',
#  'MD',
#  'simulations',
#  '.',
#  'The',
#  'adaptive',
#  'MD',
#  'launched',
#  'periods',
#  'of',
#  'multiple',
#  'parallel',
#  'MD',
#  'trajectories',
#  ',',
#  'and',
#  'the',
#  'starting',
#  'points',
#  'of',
#  'each',
#  'period',
#  'were',
#  'selected',
#  'so',
#  'as',
#  'to',
#  'favour',
#  'the',
#  'exploration',
#  'of',
#  'new',
#  'states',
#  '(',
#  'Methods',
#  ',',
#  'Supplementary',
#  'Methods',
#  '1',
#  ')',
#  '.',
#  'This',
#  'strategy',
#  'can',
#  'yield',
#  'large',
#  'speed-ups',
#  'compared',
#  'to',
#  'non-adaptive',
#  'MD',
#  'runs',
#  'because',
#  'slow',
#  'processes',
#  'with',
#  'large',
#  'energy',
#  'barriers',
#  'are',
#  'broken',
#  'down',
#  'into',
#  'steps',
#  'with',
#  'individually',
#  'smaller',
#  'barriers',
#  'that',
#  'can',
#  'be',
#  'sampled',
#  'efficiently25–27',
#  '(',
#  'Fig',
#  '.',
#  '1a',
#  ',',
#  'b',
#  ')',
#  '.',
#  'When',
#  'starting',
#  'from',
#  'the',
#  'dissociated',
#  'state',
#  ',',
#  'both',
#  'adaptive',
#  'and',
#  'non-adaptive',
#  '1Department',
#  'of',
#  'Mathematics',
#  'and',
#  'Computer',
#  'Science',
#  ',',
#  'Freie',
#  'Universität',
#  'Berlin',
#  ',',
#  'Arnimallee',
#  '6',
#  ',',
#  '14195',
#  'Berlin',
#  ',',
#  'Germany',
#  '.',
#  '2Computational',
#  'Biophysics',
#  'Laboratory',
#  '(',
#  'GRIB-IMIM',
#  ')',
#  ',',
#  'Universitat',
#  'Pompeu',
#  'Fabra',
#  ',',
#  'Barcelona',
#  'Biomedical',
#  'Research',
#  'Park',
#  '(',
#  'PRBB',
#  ')',
#  ',',
#  'C/',
#  'Doctor',
#  'Aiguader',
#  '88',
#  ',',
#  '08003',
#  'Barcelona',
#  ',',
#  'Spain',
#  '.',
#  '3Institució',
#  'Catalana',
#  'de',
#  'Recerca',
#  'i',
#  'Estudis',
#  'Avançats',
#  '(',
#  'ICREA',
#  ')',
#  ',',
#  'Passeig',
#  'Lluis',
#  'Companys',
#  '23',
#  ',',
#  '08010',
#  'Barcelona',
#  ',',
#  'Spain',
#  '.',
#  '*e-mail',
#  ':',
#  'nuria.plattner',
#  '@',
#  'fu-berlin.de',
#  ';',
#  'frank.noe',
#  '@',
#  'fu-berlin.de',
#  'ARTICLES',
#  'PUBLISHED',
#  'ONLINE',
#  ':',
#  '5',
#  'JUNE',
#  '2017',
#  '|',
#  'DOI',
#  ':',
#  '10.1038/NCHEM.2785',
#  'NATURE',
#  'CHEMISTRY',
#  '|',
#  'ADVANCE',
#  'ONLINE',
#  'PUBLICATION',
#  '|',
#  'www.nature.com/naturechemistry',
#  '1',
#  '©',
#  '2017',
#  'Macmillan',
#  'Publishers',
#  'Limited',
#  ',',
#  'part',
#  'of',
#  'Springer',
#  'Nature',
#  '.',
#  'All',
#  'rights',
#  'reserved',
#  '.',
#  'mailto',
#  ':',
#  'nuria.plattner',
#  '@',
#  'fu-berlin.de',
#  'mailto',
#  ':',
#  'frank.noe',
#  '@',
#  'fu-berlin.de',
#  'http',
#  ':',
#  '//dx.doi.org/10.1038/nchem.2785',
#  'http',
#  ':',
#  '//www.nature.com/naturechemistry',
#  'simulations',
#  'reproducibly',
#  'found',
#  'the',
#  'native',
#  'bound',
#  'complex',
#  '.',
#  'Adaptive',
#  'simulations',
#  'required',
#  'a',
#  'total',
#  'simulation',
#  'effort',
#  'of',
#  'a',
#  'few',
#  'microseconds',
#  ',',
#  'roughly',
#  'an',
#  'order',
#  ...]

# %%
text = nltk.Text(tokens)

# %%
textname = text.name
print(textname)
text.name
# Out:
# Complete protein-protein association kinetics in atomic detail revealed...
# 'Complete protein-protein association kinetics in atomic detail revealed...'

# %%
# Collocations: words occuring together
text.collocations(num=10)
# Out:
# NATURE CHEMISTRY; loosely bound; bound state; molecular dynamics;
# Supplementary Methods; wild type; Macmillan Publishers; Publishers
# Limited; rights reserved; protein–protein association

# %%
# find common context of two words
text.common_contexts(["binding", "association"])
# Out:
# the_rate

# %%
# occurances of expression within context
text.concordance('Markov' and 'molecular' and 'atomic', width=100, lines=3)
# Out:
# Displaying 3 of 5 matches:
#  atomic detail revealed by molecular dynamic
# tein–protein association kinetics in atomic detail revealed by molecular dynamic
# ociated , intermediates , etc . ) in atomic resolution , their equilibrium popul

# %%
# occurances of expression within context as list
conclist = text.concordance_list('Markov' and 'molecular' and 'atomic')
for n, item in enumerate(conclist):
    print (n)
    print (conclist[n])
# Out:
# 0
# ConcordanceLine(left=[], query='atomic', right=['detail', 'revealed', 'by', 'molecular', 'dynamics', 'simulations', 'and', 'Markov', 'modelling', 'Complete', 'protein–protein', 'association', 'kinetics', 'in', 'atomic', 'detail', 'revealed', 'by'], offset=5, left_print='', right_print='detail revealed by molecular dynami', line=' atomic detail revealed by molecular dynami')
# 1
# ConcordanceLine(left=['protein-protein', 'association', 'kinetics', 'in', 'atomic', 'detail', 'revealed', 'by', 'molecular', 'dynamics', 'simulations', 'and', 'Markov', 'modelling', 'Complete', 'protein–protein', 'association', 'kinetics', 'in'], query='atomic', right=['detail', 'revealed', 'by', 'molecular', 'dynamics', 'simulations', 'and', 'Markov', 'modelling', 'Nuria', 'Plattner1*', ',', 'Stefan', 'Doerr2', ',', 'Gianni', 'De', 'Fabritiis2,3'], offset=20, left_print='ein–protein association kinetics in', right_print='detail revealed by molecular dynami', line='ein–protein association kinetics in atomic detail revealed by molecular dynami')
# 2
# ConcordanceLine(left=['model', 'would', 'involve', 'representative', 'samples', 'of', 'all', 'structures', '(', 'bound', ',', 'dissociated', ',', 'intermediates', ',', 'etc', '.', ')', 'in'], query='atomic', right=['resolution', ',', 'their', 'equilibrium', 'populations', 'and', 'the', 'transition', 'rates', 'between', 'them', '.', 'However', ',', 'such', 'a', 'complete', 'microscopic'], offset=327, left_print='ciated , intermediates , etc . ) in', right_print='resolution , their equilibrium popu', line='ciated , intermediates , etc . ) in atomic resolution , their equilibrium popu')
# 3
# ConcordanceLine(left=['2014', ')', '.', '3', '.', 'King', ',', 'N.', 'P.', 'et', 'al', '.', 'Computational', 'design', 'of', 'self-assembling', 'protein', 'nanomaterials', 'with'], query='atomic', right=['level', 'accuracy', '.', 'Science', '336', ',', '1171–1174', '(', '2012', ')', '.', '4', '.', 'Schreiber', ',', 'G.', ',', 'Haran'], offset=6556, left_print='sembling protein nanomaterials with', right_print='level accuracy . Science 336 , 1171', line='sembling protein nanomaterials with atomic level accuracy . Science 336 , 1171')
# 4
# ConcordanceLine(left=[':', '//acellera.com', 'http', ':', '//dx.doi.org/10.1038/nchem.2785', 'http', ':', '//www.nature.com/reprints', 'http', ':', '//dx.doi.org/10.1038/nchem.2785', 'http', ':', '//www.nature.com/naturechemistry', 'Complete', 'protein–protein', 'association', 'kinetics', 'in'], query='atomic', right=['detail', 'revealed', 'by', 'molecular', 'dynamics', 'simulations', 'and', 'Markov', 'modelling', 'Results', 'and', 'discussion', 'All-atom', 'simulation', 'of', 'reversible', 'protein–protein', 'association'], offset=8648, left_print='ein–protein association kinetics in', right_print='detail revealed by molecular dynami', line='ein–protein association kinetics in atomic detail revealed by molecular dynami')

# %%
# count number of occurences
text.count('Markov')
# Out:
# 23

# %%
# Dispersion plot for word occurences
text.dispersion_plot(['simulation', 'kinetics', 'Markov'])

# %%
text.findall("<MD><simulations>")
# Out:
# MD simulations; MD simulations; MD simulations; MD simulations; MD
# simulations; MD simulations; MD simulations; MD simulations; MD
# simulations; MD simulations

# %%
text.index('MD')
# Out:
# 87

# %%
text[82:89]
# Out:
# ['by', 'direct', 'molecular', 'dynamics', '(', 'MD', ')']

# %%
text.plot(30)

# %%
text.similar('simulation')
# Out:
# structure set parts flexibility validation complex discretization
# wild-type contact characterization pre-bound future s.d discovery
# desolvation onset association probability density exploration

# %%
text.unicode_repr()
# Out:
# '<Text: Complete protein-protein association kinetics in atomic detail revealed...>'

# %%
# analyze text vocabulary
vocabulary = text.vocab()
vocabulary
# Out:
# FreqDist({'.': 569, ',': 503, 'the': 328, 'of': 245, '(': 198, ')': 198, 'and': 197, 'to': 103, 'a': 99, 'in': 84, ...})

# %%
vocabulary.freq('simulation')
# Out:
# 0.0025909532548850263

# %%
vocabulary.most_common(n=5)
# Out:
# [('.', 569), (',', 503), ('the', 328), ('of', 245), ('(', 198)]

# %%
vocabulary.keys()
# Out:
# dict_keys(['//www.nature.com/reprints', 'change', '958/A4', 'by', 'trajectory', 'computational', 'reveal', 'mandatory', 'MD', 'major', 'nuria.plattner', 'b', '/PreserveDICMYKValues', '/K', 'interaction', 'OFCOM_PO_P1_F60', 'idea', 'Models', '/CheckCompliance', 'rights', 'mediated', 'oligomerization', 'availability', 'Gabdoulline', '104', 'state22', 'principles', 'Separation', 'Fersht', 'At', 'funnel', 'surface', 'associ-', 'misbound', 'based', 'All-atom', 'Discrete', 'further', 'estimate', 'carried', 'charge', 'slow', 'starting', 'DNA', 'mol–1', 'collectively', '/QFactor', 'concentration-independent', '28.5', '1.3', 'prevented', 'fourth', '/Description', '2014', 'native', 'wild-type', 'passage', 'concentration', '/DCTEncode', 'assignment', 'kinetic', 'strategy', 'subsequently', '/Bicubic', '5c', 'representative', 'As', '40', 'deeper', 'Arrow', 'prototypical', 'then', 'predict', 'NO', 'height', 'G', 'thus', 'addressed', 'M', 'protein–protein', 'milliseconds', '3.5', 'SoOPic', '108', 'T.', '0.06', 'or', 'adaptive', 'landscapes', 'low', '/EncodeColorImages', 'Advances', 'χ1', 'U1A–SL2', 'individual', 'unknown', '(', 'hidden', '41', '10–1', 'density', 'populates', 'Deutsche', 'immediately', 'response', 'exceeded', 'ribonuclease', 'insight', '-1', 'intermediates', 'PDF', 'large', 'tryptophan', '2005', 'ϕ', 'escape', 'www.nature.com/naturechemistry', 'Lao', '/LeaveColorUnchanged', 'HTMD', '7', '/Quality', 's', 'high-', '6', '635–655', '/DAN', 'experiences', '184114', 'diffusion-map-directed', 'hitting', '/DetectCurves', 'higher', 'Mathematical', 'resolution', 'patterns', 'site', 'Schematic', 'depends', 'results', '47', 'Structurally', 'Free-energy', 'Asp', 'kon', 'Giorgino', 'make', '/AllowPSXObjects', '...', 'fu-berlin.de', 'discussion', 'model', 'lower', '44', 'b→', 'broad', 'validation', '12935–12942', 'inmed-', 'period', '/ColorImageDepth', 'leads', 'limited', '65', 'well', 'thousand', '5', 'reduce', 'Scott', 'observable', 'loosely', 'onset', 'FEDER', 'programs', '2008', 'mailto', 'residue–residue', '/DownsampleColorImages', 'Network', 'evolution', 'absolute', 'assisted', 'fit', '35', 'Notes', 'defined', 'ensembles', '2001', 'compared', 'atom', '015102', 'proceeds', 'tested', '2Computational', 'GRIB-IMIM', 'SFB', 'method', '1.0', 'Efficient', 'consists', 'atomic-detail', 'From', 'bulk', 'anassociation', 'size', '5.0', 'reproducing', '130', '3789–3798', 'modelling14–19', 'lagtime', 'effect', 'they', '/CCITTFaxEncode', 'nm', 'this', 'scaffolds', '2,000', 'quite', 'barnase–barstar', 'perform', 'Clementi', 'these', 'macromolecular', 'wide', 'Chem', '/AutoFilterGrayImages', 'Passeig', 'with', 'barstar', 'fraction', '896–908', 'energetics', 'variety', 'life', '...', 'calculating', '/ConvertImagesToIndexed', 'a', 'mutation24', '/OK', 'To', 'influenced', 'E73A', 'long-timescale', 'opens', 'intrinsic', 'chain', 'μ', 'NATURE', 'metric14', 'edge', 'self-assembling', 'right', 'trajectories25–27', 'comprising', 'previously49', 'g', 're-', '/EncodeMonoImages', 'StG', 'several', 'linear', 'english', 'compute', '–', 'ensemble', 'would', 'both', ':', 'long', 'could', '/NOR', '117', '926–935', '/PageSize', 'mutants', 'high-throughput', '18,000', 'trapping', 'orientation', '/NeverEmbed', 'bacterial', 'simulations13', '2.5', 'NPG', 'periods', 'pro-', 'almost', '0.50', 'methods', 'Markov', '/GrayImageMinResolutionPolicy', 'sRGB', 'go', 'interests', '787–794', 'bimolecular', 'blue/red', 't+50', '/AutoPositionEPSFiles', 'under', 'barnase/barstar', 'water', '3b→', 'unbiased', 'B.', 'Anderson', '2015', 'away', 'Mol', 'patches', 'stochastic', 'E73', '1.00000', 'J.', 'experimentally', '/ITA', 'These', 'msm', '4,094', 'k-means', 'im', 'kji', '23', 'conditions', 'rate-limiting', 'during', 't', '1,892', 'Avançats', 'atoms', 'once', 'electrostatically', 'bio-molecular', '90', 'landscape', 'figurations', 'fast-folding', '139', 'Gruebele', 'Total', 'separated', 'project', 'Geyer', 'thermodynamics', '/CompressPages', 'Author', '36.28000', 'Dror', 'conformations' ...

# %%
vocabulary['simulation']
# Out:
# 24
